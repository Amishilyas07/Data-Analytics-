# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Google Playstore Apps\Cleaning in Python\CleanedPlaystore.csv')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                   Sya9a Maroc - FR               FAMILY
# 10835                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10836                             Parkinson Exercices FR              MEDICAL
# 10837                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10838      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.shape
# Out:
# (10839, 13)

# %%
df.describe()
# Out:
#              Rating       Reviews      Installs         Price
# count  10839.000000  1.083900e+04  1.083900e+04  10839.000000
# mean       4.206467  4.441939e+05  1.546577e+07      1.027463
# std        0.480363  2.927893e+06  8.503315e+07     15.950436
# min        1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%        4.100000  3.800000e+01  3.000000e+03      0.000000
# 50%        4.300000  2.094000e+03  1.000000e+05      0.000000
# 75%        4.500000  5.478300e+04  5.000000e+06      0.000000
# max        5.000000  7.815831e+07  1.000000e+09    400.000000

# %%
df[df['Price']>'0']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df[df['Price']>'0']
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
df[df['Category']=='1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# # Removed Incorrect column

# %%
for i in df.index:
  if df.loc[i,'Category'] == '1.9':
    df.drop(i,inplace=True)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # Checking DataTypes and info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10839 entries, 0 to 10838
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  int64
#  4   Size            10839 non-null  object
#  5   Installs        10839 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  float64
#  8   Content Rating  10839 non-null  object
#  9   Last Updated    10839 non-null  object
#  10  Current Ver     10839 non-null  object
#  11  Android Ver     10839 non-null  object
#  12  Genres          10839 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# # Checking Unique Values

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
df['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , 4.8, 4.9,
#        3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8, 2.7,
#        1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %%
df['Rating'].mean()
# Out:
# np.float64(4.206467386290248)

# %%
df['Rating'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # Filling Na in Ratings

# %%
df['Rating'].fillna(df['Rating'].median(),inplace=True)

# %%
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews  Size  Installs  Type  Price Content Rating      Last Updated  \
# 0      159   19M     10000  Free    0.0       Everyone   January 7, 2018
# 1      967   14M    500000  Free    0.0       Everyone  January 15, 2018
# 2    87510  8.7M   5000000  Free    0.0       Everyone    August 1, 2018
#
#   Current Ver   Android Ver        Genres
# 0       1.0.0  4.0.3 and up  Art & Design
# 1       2.0.0  4.0.3 and up  Art & Design
# 2       1.2.4  4.0.3 and up  Art & Design

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10839 entries, 0 to 10838
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  int64
#  4   Size            10839 non-null  object
#  5   Installs        10839 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  float64
#  8   Content Rating  10839 non-null  object
#  9   Last Updated    10839 non-null  object
#  10  Current Ver     10839 non-null  object
#  11  Android Ver     10839 non-null  object
#  12  Genres          10839 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
df['Reviews'].unique()
# Out:
# array([   159,    967,  87510, ...,    603,   1195, 398307])

# %% [markdown]
# # Converted Reviews to Int

# %%
df['Reviews']=df['Reviews'].astype(int)

# %%
df['Reviews'].unique()
# Out:
# array([   159,    967,  87510, ...,    603,   1195, 398307])

# %%
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews  Size  Installs  Type  Price Content Rating      Last Updated  \
# 0      159   19M     10000  Free    0.0       Everyone   January 7, 2018
# 1      967   14M    500000  Free    0.0       Everyone  January 15, 2018
# 2    87510  8.7M   5000000  Free    0.0       Everyone    August 1, 2018
#
#   Current Ver   Android Ver        Genres
# 0       1.0.0  4.0.3 and up  Art & Design
# 1       2.0.0  4.0.3 and up  Art & Design
# 2       1.2.4  4.0.3 and up  Art & Design

# %% [markdown]
# # Cleaning Installs Column

# %%
df['Installs'].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,         50,        100,
#               500,         10,          1,          5,          0])

# %%
df['Installs']=df['Installs'].replace(',','',regex=True)

# %%
df['Installs'] = df['Installs'].str.rstrip('+')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df['Installs'] = df['Installs'].str.rstrip('+')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
df['Installs']=df['Installs'].astype('int')

# %%
df['Installs'].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,         50,        100,
#               500,         10,          1,          5,          0])

# %%
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159   19M     10000  Free     0       Everyone
# 1      967   14M    500000  Free     0       Everyone
# 2    87510  8.7M   5000000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %% [markdown]
# # Dropped Null Type Row

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
df[df['Type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Last Updated, Current Ver, Android Ver, Genres]
# Index: []

# %%
for i in df.index:
  if df.loc[i,'App']=='Command & Conquer: Rivals':
    df.drop(i,inplace=True)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                   Sya9a Maroc - FR               FAMILY
# 10835                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10836                             Parkinson Exercices FR              MEDICAL
# 10837                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10838      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating      Last Updated  \
# 0      159   19M     10000  Free    0.0       Everyone   January 7, 2018
# 1      967   14M    500000  Free    0.0       Everyone  January 15, 2018
# 2    87510  8.7M   5000000  Free    0.0       Everyone    August 1, 2018
# 3   215644   25M  50000000  Free    0.0           Teen      June 8, 2018
# 4      967  2.8M    100000  Free    0.0       Everyone     June 20, 2018
#
#           Current Ver   Android Ver        Genres
# ...

# %% [markdown]
# # Fixed Price Column

# %%
df['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
df['Price']=df['Price'].str.lstrip('$')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df['Price']=df['Price'].str.lstrip('$')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
df['Price'] = df['Price'].astype('float')

# %%
df['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %% [markdown]
# # Fixed Genres COlumn

# %%
df['Genres'].unique()
# Out:
# array(['Art & Design', 'Auto & Vehicles', 'Beauty', 'Books & Reference',
#        'Business', 'Comics', 'Communication', 'Dating', 'Education',
#        'Entertainment', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Adventure', 'Arcade', 'Casual', 'Card', 'Action',
#        'Strategy', 'Puzzle', 'Sports', 'Music', 'Word', 'Racing',
#        'Simulation', 'Board', 'Trivia', 'Role Playing', 'Educational',
#        'Music & Audio', 'Video Players & Editors', 'Medical', 'Social',
#        'Shopping', 'Photography', 'Travel & Local', 'Tools',
#        'Personalization', 'Productivity', 'Parenting', 'Weather',
#        'News & Magazines', 'Maps & Navigation', 'Casino'], dtype=object)

# %%
df[['Genre1','Genre2']]=df['Genres'].str.split(';',n=1,expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df[['Genre1','Genre2']]=df['Genres'].str.split(';',n=1,expand=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# ...

# %%
df['Genre1'].unique()
# Out:
# array(['Art & Design', 'Auto & Vehicles', 'Beauty', 'Books & Reference',
#        'Business', 'Comics', 'Communication', 'Dating', 'Education',
#        'Entertainment', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Adventure', 'Arcade', 'Casual', 'Card', 'Action',
#        'Strategy', 'Puzzle', 'Sports', 'Music', 'Word', 'Racing',
#        'Simulation', 'Board', 'Trivia', 'Role Playing', 'Educational',
#        'Music & Audio', 'Video Players & Editors', 'Medical', 'Social',
#        'Shopping', 'Photography', 'Travel & Local', 'Tools',
#        'Personalization', 'Productivity', 'Parenting', 'Weather',
#        'News & Magazines', 'Maps & Navigation', 'Casino'], dtype=object)

# %%
df.drop(columns='Genre2',inplace=True)

# %%
df.drop(columns='Genres',inplace=True)

# %%
df.rename(columns={'Genre1':'Genres'},inplace=True)

# %%
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews  Size  Installs  Type  Price Content Rating      Last Updated  \
# 0      159   19M     10000  Free    0.0       Everyone   January 7, 2018
# 1      967   14M    500000  Free    0.0       Everyone  January 15, 2018
# 2    87510  8.7M   5000000  Free    0.0       Everyone    August 1, 2018
#
#   Current Ver   Android Ver        Genres
# 0       1.0.0  4.0.3 and up  Art & Design
# 1       2.0.0  4.0.3 and up  Art & Design
# 2       1.2.4  4.0.3 and up  Art & Design

# %%
df['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
df['Current Ver']=df['Current Ver'].fillna('Not Avaliable')

# %%
df['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10839 entries, 0 to 10838
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  int64
#  4   Size            10839 non-null  object
#  5   Installs        10839 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  float64
#  8   Content Rating  10839 non-null  object
#  9   Last Updated    10839 non-null  object
#  10  Current Ver     10839 non-null  object
#  11  Android Ver     10839 non-null  object
#  12  Genres          10839 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
df['Android Ver'] = df['Android Ver'].fillna('Not Avaliable')

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size  Installs  Type  Price Content Rating        Last Updated  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10839 entries, 0 to 10838
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  int64
#  4   Size            10839 non-null  object
#  5   Installs        10839 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  float64
#  8   Content Rating  10839 non-null  object
#  9   Last Updated    10839 non-null  object
#  10  Current Ver     10839 non-null  object
#  11  Android Ver     10839 non-null  object
#  12  Genres          10839 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#              Rating       Reviews      Installs         Price
# count  10839.000000  1.083900e+04  1.083900e+04  10839.000000
# mean       4.206467  4.441939e+05  1.546577e+07      1.027463
# std        0.480363  2.927893e+06  8.503315e+07     15.950436
# min        1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%        4.100000  3.800000e+01  3.000000e+03      0.000000
# 50%        4.300000  2.094000e+03  1.000000e+05      0.000000
# 75%        4.500000  5.478300e+04  5.000000e+06      0.000000
# max        5.000000  7.815831e+07  1.000000e+09    400.000000

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
x= df.corr(numeric_only=True)

# %%
sns.heatmap(x,annot=True)
# Out:
# <Axes: >

# %%
df.to_csv(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Google Playstore Apps\Cleaning and Analysis in Python\CleanedPlaystore.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df.to_csv(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Google Playstore Apps\Cleaning and Analysis in Python\CleanedPlaystore.csv',index=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df.to_excel(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Google Playstore Apps\Cleaning and Analysis in Python\CleanedPlaystore.xlsx',index=False)
