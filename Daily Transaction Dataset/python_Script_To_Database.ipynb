# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import pymysql
from sqlalchemy import create_engine

# %%
df = pd.read_csv(r'Daily_Household.csv')

# %%
df.head()
# Out:
#                   Date                   Mode        Category  \
# 0  20/09/2018 12:04:08                   Cash  Transportation
# 1  20/09/2018 12:03:15                   Cash            Food
# 2           19/09/2018  Saving Bank account 1    subscription
# 3  17/09/2018 23:41:17  Saving Bank account 1    subscription
# 4  16/09/2018 17:15:08                   Cash       Festivals
#
#                Subcategory                         Note  Amount  \
# 0                    Train         2 Place 5 to Place 0    30.0
# 1                   snacks  Idli medu Vada mix 2 plates    60.0
# 2                  Netflix         1 month subscription   199.0
# 3  Mobile Service Provider            Data booster pack    19.0
# 4             Ganesh Pujan                  Ganesh idol   251.0
#
#   Income/Expense Currency
# 0        Expense      INR
# 1        Expense      INR
# 2        Expense      INR
# 3        Expense      INR
# 4        Expense      INR

# %%
db_config = {
    'database':'daily_household_db',
    'Hostname':'127.0.0.1',
    'Port':3306,
    'Username':'root',
    'Password':'7867'
}

# %%
connection_string = f"mysql+pymysql://{db_config['database']}"

# %%
connection_string = f"mysql+pymysql://{db_config['Username']}:{db_config['Password']}@{db_config['Hostname']}:{db_config['Port']}/{db_config['database']}"

# %%
db = create_engine(connection_string)

# %%
con = db.connect()

# %%
df.to_sql('Daily_Household',con=con,if_exists='replace',index=False)
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_2936\3739890333.py:1: UserWarning: The provided table name 'Daily_Household' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql('Daily_Household',con=con,if_exists='replace',index=False)
# 2461
