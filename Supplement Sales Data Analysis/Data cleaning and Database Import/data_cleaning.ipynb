# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# # Business Problem
#
# The company aims to evaluate how various health supplement products have performed across platforms (Amazon, Walmart, iHerb) and regions (USA, UK, Canada) from 2020 to 2025. This analysis will uncover sales trends, assess the effectiveness of discounts, examine pricing strategies, and evaluate product return behavior. The goal is to identify revenue drivers, understand platform and category performance, and optimize pricing and promotional strategies to support better business decisions in marketing, inventory, and pricing policy.

# %%
df = pd.read_csv(r'Supplement_Sales_Weekly_Expanded.csv')

# %%
df.head()
# Out:
#          Date  Product Name     Category  Units Sold  Price  Revenue  \
# 0  2020-01-06  Whey Protein      Protein         143  31.98  4573.14
# 1  2020-01-06     Vitamin C      Vitamin         139  42.51  5908.89
# 2  2020-01-06      Fish Oil        Omega         161  12.91  2078.51
# 3  2020-01-06  Multivitamin      Vitamin         140  16.07  2249.80
# 4  2020-01-06   Pre-Workout  Performance         157  35.47  5568.79
#
#    Discount  Units Returned Location Platform
# 0      0.03               2   Canada  Walmart
# 1      0.04               0       UK   Amazon
# 2      0.25               0   Canada   Amazon
# 3      0.08               0   Canada  Walmart
# 4      0.25               3   Canada    iHerb

# %% [markdown]
# # Data Cleaning

# %%
df.shape
# Out:
# (4384, 10)

# %%
df.isna().sum()
# Out:
# Date              0
# Product Name      0
# Category          0
# Units Sold        0
# Price             0
# Revenue           0
# Discount          0
# Units Returned    0
# Location          0
# Platform          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4384 entries, 0 to 4383
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            4384 non-null   object
#  1   Product Name    4384 non-null   object
#  2   Category        4384 non-null   object
#  3   Units Sold      4384 non-null   int64
#  4   Price           4384 non-null   float64
#  5   Revenue         4384 non-null   float64
#  6   Discount        4384 non-null   float64
#  7   Units Returned  4384 non-null   int64
#  8   Location        4384 non-null   object
#  9   Platform        4384 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 342.6+ KB

# %%
df['Order_Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#          Date  Product Name     Category  Units Sold  Price  Revenue  \
# 0  2020-01-06  Whey Protein      Protein         143  31.98  4573.14
# 1  2020-01-06     Vitamin C      Vitamin         139  42.51  5908.89
# 2  2020-01-06      Fish Oil        Omega         161  12.91  2078.51
# 3  2020-01-06  Multivitamin      Vitamin         140  16.07  2249.80
# 4  2020-01-06   Pre-Workout  Performance         157  35.47  5568.79
#
#    Discount  Units Returned Location Platform Order_Date
# 0      0.03               2   Canada  Walmart 2020-01-06
# 1      0.04               0       UK   Amazon 2020-01-06
# 2      0.25               0   Canada   Amazon 2020-01-06
# 3      0.08               0   Canada  Walmart 2020-01-06
# 4      0.25               3   Canada    iHerb 2020-01-06

# %%
for i in df.columns:
    sns.histplot(data=df,x=i,kde=True)
    plt.show()

# %%
for i in df.columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
for i in df.columns:
   print(df[i].name)
   print(len(df[i].unique()))
   print(df[i].unique())
# Out:
# Date
# 274
# ['2020-01-06' '2020-01-13' '2020-01-20' '2020-01-27' '2020-02-03'
#  '2020-02-10' '2020-02-17' '2020-02-24' '2020-03-02' '2020-03-09'
#  '2020-03-16' '2020-03-23' '2020-03-30' '2020-04-06' '2020-04-13'
#  '2020-04-20' '2020-04-27' '2020-05-04' '2020-05-11' '2020-05-18'
#  '2020-05-25' '2020-06-01' '2020-06-08' '2020-06-15' '2020-06-22'
#  '2020-06-29' '2020-07-06' '2020-07-13' '2020-07-20' '2020-07-27'
#  '2020-08-03' '2020-08-10' '2020-08-17' '2020-08-24' '2020-08-31'
#  '2020-09-07' '2020-09-14' '2020-09-21' '2020-09-28' '2020-10-05'
#  '2020-10-12' '2020-10-19' '2020-10-26' '2020-11-02' '2020-11-09'
#  '2020-11-16' '2020-11-23' '2020-11-30' '2020-12-07' '2020-12-14'
#  '2020-12-21' '2020-12-28' '2021-01-04' '2021-01-11' '2021-01-18'
#  '2021-01-25' '2021-02-01' '2021-02-08' '2021-02-15' '2021-02-22'
#  '2021-03-01' '2021-03-08' '2021-03-15' '2021-03-22' '2021-03-29'
#  '2021-04-05' '2021-04-12' '2021-04-19' '2021-04-26' '2021-05-03'
# ...

# %% [markdown]
# # Data was Cleaned Just changed type of Date Column Will perform Transformation in SQL

# %%
df.to_csv('E:/New folder E/Data Analyst Roadmap/Data Science Roadmap Campus X/Data Analytics Practice From Scratch/SQL+Python/Supplement Sales Data/Data cleaning and Database Import/Supplement_Sales_Data_cleaned.csv', index=False)
