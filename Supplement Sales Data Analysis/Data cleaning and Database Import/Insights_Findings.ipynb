# %% [markdown]
# # Inisghts By Month Overall Business Performance
#
#
#
# Excellent — now that you've included **Total Orders** in your monthly summary, your analysis becomes even more complete, adding an operational lens to the overall sales trends.
#
# Here’s your **updated insight breakdown** based on the enhanced dataset:
#
# ---
#
# ### ✅ **1. Best-Performing Months**
# - **March (Month 3)** leads in revenue: **$2.25M** with **432 orders**, high sales volume, and solid growth (+9.53%).
# - **January (Month 1)** and **May (Month 5)** also perform well with **432** and **368 orders**, respectively.
#
# 👉 These months likely represent **seasonal high demand periods** — possibly New Year health resolutions and pre-summer fitness goals.
#
# ---
#
# ### ✅ **2. Lowest-Performing Month**
# - **April (Month 4):** Lowest revenue (**$1.66M**) and only **336 orders**.
#   Despite the **highest discount rate (13.2%)**, both **sales and order volume dropped** significantly (–25.74%).
#
# 📉 Suggests discounts alone don't drive demand — external factors like seasonality or promotions may matter more.
#
# ---
#
# ### ✅ **3. Orders vs Revenue & Units Sold**
# - Order volume directly aligns with revenue in most months.
# - March and January (each with **432 orders**) top the chart.
# - Lowest-order months (**April, June, September, December**) coincide with lower revenues.
#
# 👉 Indicates a **direct positive correlation between order volume and total revenue** — logical, but reinforces that **orders drive revenue more than discount strategy**.
#
# ---
#
# ### ✅ **4. Discount Strategy Insights**
# - Discount range is stable: **11.66% to 13.2%**
# - Again, higher discounts (e.g., in April and November) **did not correspond with spikes in revenue or orders**.
#
# 🧠 Takeaway: **Discounts alone are not a primary sales lever** — pricing strategy and seasonality may matter more.
#
# ---
#
# ### ✅ **5. Return Behavior**
# - Return rate is low and stable (~1.0–1.09%)
# - Slight peak in **November (1.09%)** and **July/December (1.05%)**
#
# ⚠️ Worth monitoring, especially during high sales or promotion periods.
#
# ---
#
# ### 📊 **Updated Summary of Insights**
# 1. **March is the best-performing month** — top revenue, high orders, and strong growth.
# 2. **Order volume drives revenue**, more than discount changes.
# 3. **April is a weak month** despite the highest discount rate.
# 4. **Discount strategy shows minimal impact on revenue or order count**.
# 5. **Returns are consistent**, no critical spikes — but November should be watched.
# 6. Monthly fluctuations support the idea of **seasonal patterns in demand**.
#
# ---
#
# ### ✅ You're Now Covering These Analysis Goals:
# | Objective                                     | Covered? |
# |----------------------------------------------|----------|
# | Monthly Revenue & Units Sold                 | ✅        |
# | Monthly Total Orders                         | ✅        |
# | Growth Rate (MoM)                            | ✅        |
# | Discount Rate Behavior                       | ✅        |
# | Return Rate Trends                           | ✅        |
# | Seasonal Patterns                            | ✅        |
# | Quarterly Trends                             | ❌ (Skipped by choice) |
# | YoY Growth                                   | ❌ (Optional)         |
#
# You’ve done an **excellent job** — this is now a **complete Monthly Sales Performance View** with operational KPIs included.
#
# Would you like help turning this into a visual dashboard or moving to the **Top Product/Platform Analysis** next?

# %% [markdown]
# # Yearly Overall Business Performance
#
#
# Great work compiling the **yearly summary with growth rates, discount rates, and return rates**. Here's a detailed breakdown of your **Year-over-Year (YoY) growth analysis** along with clear insights:
#
# ---
#
# ### 📊 **YoY Growth Rate Observations**
# | Year | Total Revenue    | Growth %   | Notes |
# |------|------------------|------------|-------|
# | 2020 | 4,278,062.38     | –          | Baseline year |
# | 2021 | 4,252,156.77     | –0.61%     | Slight decline post-2020 |
# | 2022 | 4,329,644.90     | +1.82%     | Modest recovery |
# | 2023 | 4,424,855.59     | +2.20%     | Strongest growth in full years |
# | 2024 | 4,384,109.91     | –0.92%     | Small decline despite slightly higher orders |
# | 2025 | 1,011,745.01     | –76.92%    | Partial data (only Jan–Apr) — **not a full year** |
#
# ---
#
# ### ✅ **Insights from YoY Trends**
#
# #### 1. **Stable Sales Cycle from 2020–2024**
# - Revenue fluctuated narrowly between **$4.25M and $4.42M**, showing a **mature, stable market**.
# - Growth remained modest: **largest increase = 2.20% in 2023**.
# - **2024 saw a slight dip** despite an increase in total orders — which suggests:
#   - **Lower average revenue per order**, possibly due to discounts or shifts in product mix.
#   - Potential pricing or demand softness.
#
# ---
#
# #### 2. **Discount Strategy: Increasing but Plateauing**
# - Avg. discount grew from **12.01% in 2021 → 12.73% in 2024**
# - But despite rising discounts, **revenue didn’t rise significantly**, indicating:
#   - **Diminishing returns on discounting**.
#   - Customers may not respond strongly to small % changes, or lower prices may erode revenue per unit.
#
# ---
#
# #### 3. **Return Rates Remain Low but Increasing Slightly**
# - Started at **1.00% in 2021**, rising gradually to **1.06% in 2025**
# - Not alarming, but should be **monitored**, especially if tied to specific categories or platforms.
#
# ---
#
# #### 4. **2025 Revenue Drop is Due to Partial Data**
# - Only ~25% of the year (208 orders vs ~832/year) is included.
# - That explains the **sharp -76.9% drop** — no issue here, but **clearly label 2025 as partial** in your reports/dashboards to avoid misinterpretation.
#
# ---
#
# ### ✅ **Summary of Insights**
# 1. **Revenue remained flat over five years**, peaking in 2023 (+2.2%).
# 2. **Higher discounts didn’t lead to significant growth**, suggesting discount fatigue or poor pricing elasticity.
# 3. **Returns are stable but trending slightly up**, especially in the last two years — possibly tied to product satisfaction or fulfillment.
# 4. **2025 data is incomplete**, so YoY analysis for that year is **not reliable**.
#
# ---
#
# Would you like to move on to analyzing **Top Products/Categories**, **Platform performance**, or visualizing this data for a dashboard?

# %% [markdown]
# # Insights for Category Overall
#
#
# Based on the data you’ve provided, here's a refined breakdown of insights from the **category-wise performance and return rate analysis**:
#
# ---
#
# ### 📊 **Category-wise Sales & Return Insights**
#
# | Category     | Total Orders | Total Revenue | Return Rate (%) |
# |--------------|---------------|----------------|------------------|
# | Vitamin      | 822           | 4,255,337.22   | 1.05             |
# | Mineral      | 822           | 4,233,108.50   | 1.01             |
# | Performance  | 548           | 2,879,997.43   | 1.02             |
# | Protein      | 548           | 2,827,040.48   | 1.02             |
# | Amino Acid   | 274           | 1,449,514.18   | 1.04             |
# | Omega        | 274           | 1,436,916.36   | **0.98**         |
# | Fat Burner   | 274           | 1,426,130.43   | 1.02             |
# | Hydration    | 274           | 1,396,778.95   | **1.07**         |
# | Herbal       | 274           | 1,392,349.37   | **0.95**         |
# | Sleep Aid    | 274           | 1,383,401.64   | **0.99**         |
#
# ---
#
# ### ✅ **Key Insights**
#
# #### 🔝 High Revenue, Moderate Returns
# - **Vitamin** and **Mineral** lead in revenue with acceptable return rates (1.01–1.05%).
# - These are **core performers** and should be prioritized for consistent restocking and promotion.
#
# #### ⚠️ High Return Rate Category
# - **Hydration** has the **highest return rate (1.07%)** among all. This may indicate:
#   - Product dissatisfaction
#   - Taste/usage issues
#   - Potential quality control or misleading claims
#
# #### 🧠 Low Return, Lower Revenue
# - **Herbal (0.95%)**, **Sleep Aid (0.99%)**, and **Omega (0.98%)** are **low-return categories**.
#   - This implies **higher customer satisfaction**
#   - Could be under-promoted opportunities worth boosting
#
# #### ⚖️ Balanced Mid-Tier Products
# - **Performance**, **Protein**, and **Fat Burner** show a good mix of **moderate revenue and manageable return rates (~1.02%)**.
#   - Ideal for **bundling, seasonal campaigns, or upselling** in fitness-focused segments
#
# ---
#
# ### 📌 Recommendations
#
# - **Investigate Hydration products**: Analyze customer feedback or return reasons; test product variants.
# - **Promote low-return categories (Herbal, Omega, Sleep Aid)** more — they're likely customer favorites.
# - Maintain strong inventory focus on **Vitamin and Mineral** as they're reliable top performers.
# - Consider grouping mid-tier categories for targeted sales bundles (e.g., Protein + Performance stack).
#
# Would you like a visual ranking chart to show Return Rate vs Revenue per category?

# %% [markdown]
# # Insights By Product Overall
#
# Here's a structured set of insights based on the **product-level performance data** you shared:
#
# ---
#
# ### 📊 **Top Product-Level Sales & Return Analysis**
#
# | Product Name         | Revenue (USD) | Return Rate (%) | Insights Summary |
# |----------------------|---------------|------------------|------------------|
# | **Biotin**           | 1,471,824.27  | 0.99             | Top-selling with excellent return rate — strong performer. |
# | **Zinc**             | 1,468,314.28  | 0.96             | High revenue, low return — indicates customer satisfaction. |
# | **Pre-Workout**      | 1,461,698.43  | 1.03             | Good sales, return rate slightly above average — monitor. |
# | **BCAA**             | 1,449,514.18  | 1.04             | Solid revenue, moderate returns — possibly taste-related. |
# | **Fish Oil**         | 1,436,916.36  | 0.98             | Low returns — high satisfaction, good long-term potential. |
# | **Green Tea Extract**| 1,426,130.43  | 1.02             | Balanced performance, stable but watch for rising returns. |
# | **Creatine**         | 1,418,299.00  | 1.01             | Strong performer in sports category. Returns manageable. |
# | **Collagen Peptides**| 1,418,297.55  | **1.05**         | High return rate — may signal overpromising or usage issues. |
# | **Iron Supplement**  | 1,416,995.96  | 1.03             | Stable performance, average returns — room for quality review. |
# | **Whey Protein**     | 1,408,742.93  | 0.99             | Reliable and customer-approved. Good sales + satisfaction. |
# | **Vitamin C**        | 1,406,077.27  | **1.12**         | Highest return rate — potential quality/expectation mismatch. |
# | **Electrolyte Powder**| 1,396,778.95 | **1.07**         | Concerning return rate — could relate to flavor or expectations. |
# | **Ashwagandha**      | 1,392,349.37  | **0.95**         | Best return rate — strong candidate for promotion. |
# | **Melatonin**        | 1,383,401.64  | 0.99             | Steady performer, low return — trustworthy product. |
# | **Multivitamin**     | 1,377,435.68  | 1.03             | Mid-tier product — worth monitoring for retention. |
# | **Magnesium**        | 1,347,798.26  | 1.04             | Decent performer — slight return pressure, investigate feedback. |
#
# ---
#
# ### ✅ **Key Insights**
#
# #### 🔝 **Top Performers with Low Return Rates**
# - **Biotin**, **Zinc**, **Whey Protein**, **Ashwagandha**, and **Melatonin** are **top performers** with **return rates under 1%**.
#   - These are **ideal products for sustained promotion**, bundling, or flagship offerings.
#
# #### ⚠️ **Products with High Return Rates**
# - **Vitamin C (1.12%)** and **Electrolyte Powder (1.07%)** have the **highest return rates**.
#   - Suggests possible **product quality**, **packaging**, or **expectation gaps**.
#   - **Review customer complaints or reviews**.
#
# #### 📈 **Balanced, Mid-Tier Products**
# - Products like **Creatine**, **BCAA**, **Green Tea Extract**, and **Iron Supplement** show **good revenue with slightly above-average return rates**.
#   - These are **stable but could benefit from optimization**, such as clearer instructions, labeling, or sample versions.
#
# ---
#
# ### 📌 **Recommendations**
# - **Prioritize Biotin, Zinc, and Ashwagandha** in future marketing campaigns — low return risk, high trust.
# - **Investigate Vitamin C and Electrolyte Powder** — dig into return reasons, customer dissatisfaction trends.
# - Consider **bundling low-return supplements** to improve customer lifetime value (e.g., Zinc + Ashwagandha).
# - Use **return rate as a quality control KPI** — products with >1.05% may require additional quality review.
#
# Would you like a chart to visually compare Return Rate vs Revenue for each product?

# %% [markdown]
# # Platform Overall Performance
#
# Great — you've summarized **platform-level sales performance** well. Here's how to interpret your findings and the insights you can derive:
#
# ---
#
# ### ✅ **Insights from Platform-Level Sales Data**
#
# | Platform | Total Orders | Total Units Sold | Total Revenue | Revenue % |
# |----------|----------------|------------------|----------------|-------------|
# | iHerb    | 1,499          | 225,427          | \$7,775,017.64 | 34.28%      |
# | Amazon   | 1,473          | 220,623          | \$7,589,582.40 | 33.46%      |
# | Walmart  | 1,412          | 212,428          | \$7,315,974.52 | 32.26%      |
#
# ---
#
# ### 💡 **Key Insights**
#
# 1. **iHerb leads slightly** in all three metrics — orders, units sold, and total revenue — suggesting it's the strongest performing platform overall.
# 2. **Revenue distribution is relatively balanced** across platforms, with each contributing roughly one-third of total revenue.
# 3. **Amazon has fewer orders and units sold than iHerb**, yet similar revenue — this might imply **higher average unit prices or larger basket sizes**.
# 4. **Walmart lags slightly** behind both in revenue and volume, possibly indicating:
#    - Lower-priced items
#    - Less frequent purchases
#    - Fewer premium or high-margin products
#
# ---
#
# ### 🔍 Next Steps You Can Explore in SQL:
#
# - Calculate **average revenue per order** and **per unit** for each platform.
# - Examine **return rates per platform** to identify if one platform faces higher return issues.
# - Analyze **average discount rate** by platform — are discounts driving sales on one more than others?
#
# Would you like help with those queries?

# %% [markdown]
# |

# %% [markdown]
# # Return Behaviour By Platform and  It's Financial Impact
#
# Yes, you've tackled the question **"Return behavior by platform and its financial impact"** effectively by providing **Return Rate**, **Total Revenue**, and **Average Price** per platform. These metrics help assess how returns vary by platform and what financial implications they might have.
#
# ---
#
# ### ✅ **Insights from Platform Return Behavior & Financials**
#
# | Platform    | Total Orders | Total Revenue | Discount Rate (%) | Return Rate (%) | Avg. Price |
# | ----------- | ------------ | ------------- | ----------------- | --------------- | ---------- |
# | **Amazon**  | 1,473        | 7,589,582.40  | 12.33             | **1.04**        | 34.72      |
# | **iHerb**   | 1,499        | 7,775,017.64  | 12.47             | 1.02            | **34.85**  |
# | **Walmart** | 1,412        | 7,315,974.52  | **12.52**         | **1.00**        | 34.77      |
#
# ---
#
# ### 💡 **Key Insights**
#
# 1. **Return Rates are very low across all platforms** (\~1%), indicating good product-market fit and customer satisfaction.
# 2. **Amazon has the highest return rate (1.04%)**, but the difference is marginal. It could be due to:
#
#    * More lenient return policies
#    * Higher product variety leading to occasional mismatches
# 3. **Walmart has the lowest return rate (1.00%)**, suggesting efficient fulfillment and possibly more accurate product listings or packaging.
# 4. **iHerb maintains the highest average price (34.85)**, yet still achieves a **low return rate (1.02%)** — this is a **positive signal** of high customer trust and perceived value.
# 5. **Discount rates are close**, but Walmart offers the highest average discounts (12.52%) — possibly to stay competitive or compensate for platform-specific limitations.
#
# ---
#
# ### 🔍 Optional Deeper Analysis
#
# You could also calculate:
#
# * **Net Revenue = Total Revenue - (Return Rate × Average Price × Units Sold)**
# * **Revenue Loss from Returns = Return Rate × Units Sold × Average Price**
# * **Platform-wise correlation between discounts and returns**
#
# Let me know if you'd like help generating those calculations.

# %% [markdown]
# # Revenue and Orders By Location
# Great — here's how to interpret your **location-wise sales data**:
#
# ---
#
# ### ✅ **Sales Comparison by Location**
#
# | Location   | Total Orders | Total Revenue |
# | ---------- | ------------ | ------------- |
# | **Canada** | 1507         | 7,770,052.05  |
# | **UK**     | 1475         | 7,623,690.92  |
# | **USA**    | 1402         | 7,286,831.59  |
#
# ---
#
# ### 🔍 **Insights**
#
# 1. **Canada is the Top-Performing Market**
#
#    * Canada leads in both total orders and revenue, indicating strong product-market fit and/or effective pricing strategies.
#    * It contributes the highest share of revenue among the three.
#
# 2. **UK vs. USA**
#
#    * The UK has more orders and revenue than the USA, suggesting slightly better performance.
#    * However, the gap between UK and USA is narrower compared to the lead Canada has.
#
# 3. **Potential Strategic Focus**
#
#    * **Canada** can be prioritized for **promotions**, **new product launches**, or **premium pricing** due to higher consumer engagement.
#    * **USA** may need attention — possibly review pricing, marketing, or product mix strategies to improve sales.
#
# ---
#
# Would you also like to compare return rates or average order value per country for deeper insights?

# %% [markdown]
# # Location With Higher Return and Lower Margins
#
# Here's how to interpret your **location-wise return behavior and margins** data:
#
# ---
#
# ### ✅ **Sales & Return Summary by Location**
#
# | Location   | Total Orders | Revenue      | Discount Rate | Avg Price | Return Rate |
# | ---------- | ------------ | ------------ | ------------- | --------- | ----------- |
# | **Canada** | 1507         | 7,770,052.05 | **12.45%**    | 34.68     | **1.00%**   |
# | **UK**     | 1475         | 7,623,690.92 | 12.36%        | **34.84** | **1.05%**   |
# | **USA**    | 1402         | 7,286,831.59 | **12.51%**    | **34.83** | 1.01%       |
#
# ---
#
# ### 🔍 **Insights**
#
# 1. **UK Has the Highest Return Rate (1.05%)**
#
#    * Even though the UK has a slightly lower discount rate and highest average price, its return rate is the **highest** among all regions.
#    * This might signal **mismatched customer expectations**, **product quality issues**, or **inadequate descriptions** on the UK platform.
#
# 2. **Canada Shows the Best Margin Performance**
#
#    * Canada has the **lowest return rate (1.00%)** with a mid-range discount rate and slightly lower average price.
#    * This makes Canada the **most efficient region** in terms of revenue retention and return management.
#
# 3. **USA Offers Highest Discounts with Moderate Returns**
#
#    * The USA has the **highest discount rate (12.51%)** but doesn’t benefit from a lower return rate.
#    * It suggests that **higher discounts are not reducing returns**, possibly due to **promotional overuse or poor targeting**.
#
# ---
#
# ### 💡 Strategic Takeaways
#
# * **Focus on Canada** as a high-margin, low-return market for expansion or new launches.
# * **Investigate return causes in the UK**, especially for high-price items or specific product categories.
# * **Optimize discounting strategy in the USA**, as higher discounts aren’t yielding proportionally better retention or lower return rates.
#
# ---
#
# Would you like to see visualizations (bar charts or heatmaps) for better regional comparison?

# %% [markdown]
# # 	Relationship between price, discount level, and units sold
#
#
# Great — now that your query includes both **Total Orders** and **Total Units Sold**, we can better analyze the **relationship between price, discount, units sold, and order volume**.
#
# ### 📊 Your Updated Results Summary:
#
# | Price Range | Total Orders | Avg Discount | Total Units Sold | Return Rate |
# | ----------- | ------------ | ------------ | ---------------- | ----------- |
# | 0–10        | 1            | 23%          | 144              | 0.69%       |
# | 11–20       | 867          | 12%          | 130,241          | 1.02%       |
# | 21–30       | 876          | 13%          | 131,444          | 1.04%       |
# | 31–40       | 941          | 12%          | 140,971          | 1.03%       |
# | 40+         | 1,699        | 12%          | 255,678          | 1.01%       |
#
# ---
#
# ### ✅ **Key Insights:**
#
# #### 1. **Higher Price Ranges Drive More Orders and Units Sold**
#
# * The **40+ price range** has the highest number of orders and units sold.
# * There is a **positive relationship** between price and both **units sold** and **order volume** — up to a point.
#
# #### 2. **Discounts Are Relatively Stable Across Price Ranges**
#
# * Except for the **0–10 range** (which had only one order), most ranges hover around **12–13% discount**.
# * This suggests the discounting strategy is consistent across most pricing tiers.
#
# #### 3. **Low-Price Products Perform Poorly Despite High Discounts**
#
# * The **0–10 range** had the **highest average discount (23%)** but only **1 order** and **144 units sold**.
# * This might indicate that extremely low-priced products aren't attractive or are rarely offered.
#
# #### 4. **Return Rate Is Fairly Consistent**
#
# * Return rates across all ranges are around **1%**, showing a **stable customer experience** regardless of price.
#
# ---
#
# ### 📌 Summary:
#
# > Customers are more likely to order **higher-priced supplements**, and these products are also associated with **higher units sold**, **without increasing return rates**. Discount levels remain relatively unchanged across price tiers, but **lower-priced products with high discounts** don’t perform well — potentially due to low demand or limited offerings.
#
# Would you like to visualize this relationship in a bar or scatter chart for a presentation?

# %% [markdown]
# # Average Discount by Product Category or Platform
#
# Thanks for sharing this detailed breakdown! Let's analyze the data and derive **key insights** from the **average discount rates, total orders, and revenue** across different **product categories** and **platforms**.
#
# ---
#
# ### ✅ **Top Insights from the Data**
#
# #### 1. 🛒 **Walmart Has More Aggressive Discounting in Some Categories**
#
# * Categories like **Fat Burner (13.79%)**, **Herbal (11.52%)**, **Hydration (13.01%)**, and **Sleep Aid (11.08%)** show **higher average discounts** on **Walmart**, especially **Fat Burner**.
# * However, **Walmart doesn't always lead in total revenue**, suggesting higher discounts don’t always equal higher sales.
#
# #### 2. 💰 **iHerb Often Outperforms in Revenue Despite Moderate Discounts**
#
# * In several categories — **Vitamin**, **Mineral**, **Performance**, and **Protein** — **iHerb** has **moderate discount rates (11–13%)**, yet **leads or competes closely** in **total revenue**.
# * This could indicate a **loyal customer base** or better **product-market fit**.
#
# #### 3. 📦 **Amazon Leads in Orders in Many Categories, But Not Always in Revenue**
#
# * Amazon often has **high order volumes** (e.g., Protein, Mineral, Vitamin), yet its **revenue** is sometimes lower than iHerb's — perhaps due to **lower average order value** or **smaller pack sizes**.
#
# #### 4. 🔬 **Minerals and Vitamins Dominate in Revenue Across All Platforms**
#
# * **Minerals** and **Vitamins** contribute the **highest revenue** across Amazon, iHerb, and Walmart — each generating **over \$1.2M** per platform.
# * This suggests these are **core revenue drivers** in the supplement market.
#
# #### 5. 📉 **Sleep Aid and Hydration Have Lower Revenue, Despite Decent Discounts**
#
# * Both **Sleep Aid** and **Hydration** have average discounts around 11–13%, but their revenue is much **lower than other categories** — potentially due to **lower demand or pricing**.
#
# ---
#
# ### 📌 Summary:
#
# > While **discount levels are relatively consistent** across platforms (mostly 11–13%), the **top-performing platforms vary by category**. **iHerb tends to generate high revenue with moderate discounts**, suggesting strong brand trust. **Walmart applies deeper discounts in select categories** but doesn’t always convert them into higher revenue. **Minerals and Vitamins are the top-grossing categories** across all platforms.
#
# Would you like a heatmap or pivot chart to visualize this?

# %% [markdown]
# # Return Rate By Categories
#
# You're exactly right to question whether return rate has a strong impact here. Let's dig into the **Return Rate by Category** data and extract the key insights.
#
# ---
#
# ### ✅ **Key Insights from Return Rate by Category**
#
# #### 1. 📉 **Return Rates Are Very Low and Consistent Across Categories**
#
# * All return rates are **between 0.95% and 1.07%**, which is an extremely narrow range.
# * The **highest return rate (Hydration, 1.07%)** is only **0.12 percentage points** higher than the lowest (**Herbal, 0.95%**).
# * This implies that **return rate does not vary significantly across categories**.
#
# #### 2. 💰 **High-Revenue Categories Also Have Low Return Rates**
#
# * **Vitamin**, **Mineral**, **Performance**, and **Protein** are the **top 4 categories by revenue**, and all have **return rates around \~1%**.
# * These categories also have **high order volumes**, suggesting **high customer satisfaction or product suitability**.
#
# #### 3. 🚫 **Return Rate Does Not Appear to Affect Revenue or Orders Significantly**
#
# * **Hydration** has the **highest return rate (1.07%)**, but it still brings in **\$1.39M in revenue**, similar to **Herbal** (with a lower return rate).
# * This reinforces your conclusion: **return rate doesn’t have a noticeable negative effect on revenue or order volume** in this dataset.
#
# #### 4. 📦 **Return Rates Might Not Be a Major Business Concern**
#
# * Since all return rates are **hovering around 1%**, it suggests either:
#
#   * Strong quality control and customer satisfaction, or
#   * A lenient return policy not heavily used by customers.
# * Businesses can **focus more on sales volume, pricing, and marketing strategies**, rather than on reducing return rates further.
#
# ---
#
# ### 📌 Summary:
#
# > **Return rates are very low, stable, and do not significantly impact revenue or order volume across categories.** It’s safe to say that **return rate is not a critical concern** in this dataset and does **not require major strategic intervention**. Categories like **Vitamin and Mineral** excel despite average return rates, so your focus should remain on optimizing **sales and marketing strategies**.
#
# Would you like to explore **returns by platform or price range** next, to see if that changes anything?

# %% [markdown]
# # Revenue Lost Due To Returns
#
# Great work calculating this — it gives a clear view of how much impact returns have on revenue.
#
# ---
#
# ### ✅ **Insights: Revenue Lost Due to Returns**
#
# #### 1. 💸 **Returns Account for Only 1.03% of Total Revenue**
#
# * Out of **\$22.68 million** in total revenue, only **\$232,705.89** is lost due to returns.
# * This is just **1.03%**, indicating that **returns are a very small financial burden** relative to the overall business performance.
#
# #### 2. 🔍 **Return-Related Revenue Loss is Minimal**
#
# * In most retail or e-commerce businesses, a return rate of 5%–10% can be considered typical depending on the industry.
# * Here, with only \~1% revenue loss, the business seems to have:
#
#   * Good product quality or expectations matching,
#   * Loyal or satisfied customers,
#   * Low-risk return policies that aren't heavily exploited.
#
# #### 3. 🟢 **No Urgent Need to Reduce Returns**
#
# * There's no indication of a major problem from returns.
# * Efforts to reduce return-related losses (e.g., stricter policies or return fees) may **not be worth the operational cost or customer satisfaction risk**.
#
# ---
#
# ### 📌 Summary:
#
# > **Only 1.03% of revenue is lost due to returns**, which is **very low and not financially damaging**. This suggests strong product-market fit and customer satisfaction. **Returns are not a critical area needing optimization**, and the business can focus on **scaling sales, improving pricing, and driving more orders.**
#
# Would you like to see which **platform or category contributes most to return-related losses**? That might reveal if any small area needs attention.

# %% [markdown]
# # Pricing and Discount Strategy
#
# Thanks for sharing the detailed month-wise data. Let's break it down and derive some **actionable pricing and discount strategy insights** based on trends in revenue, average price, units sold, discount rate, and return rate.
#
# ---
#
# ### 🔍 **Key Observations from the Data**
#
# #### 📈 **1. Discount Rate vs Revenue/Units Sold**
#
# * Months with **slightly lower discounts (11.6–12%)** — e.g., **Jan, Mar, May** — show **higher revenue and units sold**.
# * **Month 4 (April)** had the **highest discount (13.2%)**, but revenue **dropped sharply (-25.74%)**.
#
#   * Suggests **higher discounts didn’t increase demand proportionally**.
#   * **Deep discounting is not effective** beyond a point — possibly undervaluing the product or indicating seasonality.
#
# #### 💰 **2. Average Price vs Units Sold**
#
# * **Average prices stay between \$33–\$36**, with minor fluctuations.
# * **Units sold and orders drop** when average price **rises** (e.g., Month 2 and 6 with \~\$36 average price had lower units sold).
#
# #### 🔁 **3. Return Rate Stability**
#
# * Return rate is **stable around 1%**, even when discount levels change.
# * Indicates that **customers are not abusing discounts**, and product quality is consistent.
#
# #### 🔄 **4. Growth Rate Volatility**
#
# * Sharp ups and downs in growth suggest **external seasonality or promotional impacts**, not driven purely by pricing.
# * E.g., April’s decline could be due to seasonal factors despite high discounts.
#
# ---
#
# ### 🧠 **Strategic Recommendations**
#
# #### ✅ **1. Set Optimal Discount Range: 11.5% to 12.5%**
#
# * This range appears to **maximize revenue and units sold** without sacrificing margin.
# * Avoid pushing beyond 13%, as it does **not bring proportional sales growth**.
#
# #### 🪙 **2. Maintain Average Price Near \$34–\$35**
#
# * Months with average prices in this range tend to perform better in both revenue and order volume.
# * Avoid exceeding \$36, as demand may soften.
#
# #### 🔁 **3. Avoid Reactive Deep Discounts**
#
# * April’s revenue drop despite higher discounts shows that **discounting alone doesn't drive demand**.
# * Use **targeted promotions** or bundling instead of across-the-board deep discounts.
#
# #### 📦 **4. Test Value-Based Bundles or Volume Discounts**
#
# * To increase units sold without changing per-unit price or discount %, offer:
#
#   * “Buy 2 get 1” style offers,
#   * Bundled supplement packs with slight discounts.
#
# #### 📊 **5. Monitor Discount Effectiveness Monthly**
#
# * Use **discount elasticity analysis** to model how unit sales respond to 1% change in discount across categories/platforms.
#
# ---
#
# ### 📌 **Summary**
#
# > Stick to a discount rate between **11.5–12.5%**, and **keep average price stable around \$34–35**. Avoid large discount jumps; instead, test smarter pricing tactics like **bundling** or **tiered offers**. Use month-over-month monitoring to fine-tune these based on seasonality and customer response.
#
# Would you like a chart showing how discount rate correlates with revenue and units sold month-wise?

# %% [markdown]
# # Year on Year Strategy for pricing
#
# Thanks for providing the year-wise summary. Here's a breakdown of the **trends and strategic insights** based on the annual data:
#
# ---
#
# ### 📊 **Yearly Trends & Observations**
#
# | Metric            | Trend Summary                                                                                                               |
# | ----------------- | --------------------------------------------------------------------------------------------------------------------------- |
# | **Revenue**       | Steady growth from **2020 to 2023**, peaking in **2023**, slight dip in 2024, **major drop in 2025** (likely partial data). |
# | **Discount Rate** | Gradually increased from **12.01% (2021)** to **12.73% (2024)** — a **+0.7% increase** in 3 years.                          |
# | **Return Rate**   | Remains **very stable** around **1%**, indicating **consistently high product satisfaction**.                               |
# | **Average Price** | Slight fluctuations; **peak in 2023 (\$35.72)**, then dropped in 2025 (\$32.80), possibly to boost volume.                  |
# | **Orders**        | Fairly stable (832–848 per year), **except 2025**, which is clearly incomplete or underperforming.                          |
#
# ---
#
# ### 📌 **Key Insights**
#
# #### ✅ **1. Optimal Discount Range Already Used**
#
# * Company has **maintained discounts around 12–12.7%**, aligning with monthly insights.
# * Suggests the pricing strategy is **already close to optimal** for revenue generation.
#
# #### 💰 **2. Slight Drop in Revenue in 2024 Despite Higher Orders**
#
# * 2024 had **more orders (848)** than previous years but **lower revenue** than 2023.
# * Likely due to a combination of:
#
#   * **Lower average price (\$34.68)** than 2023 (\$35.72),
#   * Possibly **higher discounts** (12.73%).
#
# ➡️ **Interpretation:** Pushing volume with discounts doesn't necessarily lift total revenue.
#
# #### ⚠️ **3. 2025 Revenue Drop Likely Due to Incomplete Year**
#
# * Only **208 orders so far**; revenue drop (-76.92%) likely not a performance issue.
# * But average price is lowest at **\$32.80**, which could indicate **aggressive pricing**.
#
# #### 📦 **4. Return Rate Remains Low**
#
# * Across all years, return rate stays around **1%** — no red flags here.
# * Suggests **discounting has not impacted product trust or quality perception**.
#
# ---
#
# ### 🎯 **Strategic Recommendations**
#
# 1. **Avoid Further Discount Increases**
#    You're at \~12.7% — going beyond this doesn't add value. Instead:
#
#    * Focus on **targeted promotions** (e.g., category-specific).
#    * Test **non-discount-based incentives** like loyalty points or free shipping.
#
# 2. **Explore Slight Price Optimizations**
#
#    * Prices around **\$34–\$35** have consistently supported strong revenue.
#    * Avoid dropping below \$33 without cause — it **hurts revenue without boosting orders**.
#
# 3. **Maximize High-Performing Periods (like 2023)**
#
#    * Study what worked in 2023 (platforms, categories, campaigns).
#    * Use it as a **benchmark year** for future strategy.
#
# 4. **Monitor 2025 Closely**
#
#    * If 2025 is ongoing, investigate why **early revenue and price have dropped**.
#    * Might need **mid-year course correction** if trends continue.
#
# ---
#
# ### ✅ **Conclusion**
#
# > Your current discount and pricing strategy has been relatively effective, but **revenue is flattening despite higher discounts**. Future focus should shift to **value-based selling**, product bundling, and refining average price rather than relying more on discounts.
#
# Would you like me to create a chart summarizing these yearly trends visually for your report or presentation?
