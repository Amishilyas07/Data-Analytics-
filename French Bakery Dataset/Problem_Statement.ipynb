# %% [markdown]
# ### **Business Problem: Optimizing Sales & Inventory Management for a French Bakery**
#
# The bakery is experiencing **inconsistent sales patterns**, leading to potential issues like **overstocking, understocking, and missed revenue opportunities**. Additionally, the business is unsure about the **best-selling products, peak sales hours, and customer purchasing behavior**, making it difficult to optimize pricing, staffing, and promotions.
#
# To remain competitive and increase profitability, the bakery needs to:
# 1. **Identify high-demand products** to ensure consistent stock availability.
# 2. **Reduce waste** by analyzing slow-moving items and adjusting inventory levels.
# 3. **Optimize pricing strategies** by assessing how unit price impacts sales.
# 4. **Understand customer behavior** to improve promotions and upselling strategies.
# 5. **Determine peak business hours** to efficiently allocate staff and resources.
#
# By analyzing sales trends using **SQL and Python**, the bakery can make **data-driven decisions** to improve revenue, enhance customer experience, and streamline operations.
#
# Let me know if you'd like to refine this problem statement further! 🚀

# %% [markdown]
# That sounds like a great project! Here's how you can **approach your analysis** step by step without diving into queries:
#
# ### **1️⃣ Sales Performance Analysis**
# - Identify the **top-selling items** based on total quantity sold.
# - Find the **least-selling items**—are they seasonal or just unpopular?
# - Check **daily, weekly, and monthly trends** to see if there are any predictable sales patterns.
#
# ### **2️⃣ Customer Buying Behavior**
# - Calculate the **average ticket size** (total sales per order) to understand customer spending habits.
# - Identify **frequently bought together items** (e.g., coffee & croissants).
# - Analyze whether customers buy more during **mornings, afternoons, or evenings**.
#
# ### **3️⃣ Time-Based Analysis**
# - Create a **heatmap** of sales by hour and day to find **peak business hours**.
# - Compare sales on **weekdays vs. weekends** to see if there’s a significant difference.
# - Look for **seasonal patterns**—do sales increase around holidays?
#
# ### **4️⃣ Pricing & Discounts Impact**
# - Check whether higher or lower **unit prices affect demand**.
# - Identify products that could benefit from **price adjustments** (e.g., discounts on low-selling items).
#
# ### **5️⃣ Inventory Optimization**
# - Find items that are often **overstocked** or **understocked** based on sales trends.
# - Recommend how often specific items should be **replenished** to minimize waste.
# - Use **historical data to forecast future demand** and avoid stockouts.
#
# ### **Outcome & Recommendations**
# By analyzing these aspects, you can provide **data-driven recommendations** on:
# ✅ Which items to promote or bundle for better sales
# ✅ When to adjust staffing levels based on peak hours
# ✅ How to optimize inventory and reduce waste
# ✅ Which pricing strategies could improve profitability
#
# Once you've done the analysis, you can visualize these insights in **Power BI, Tableau, or Matplotlib/Seaborn in Python**.
#
# Would you like help structuring your report or dashboard based on these insights? 🚀
