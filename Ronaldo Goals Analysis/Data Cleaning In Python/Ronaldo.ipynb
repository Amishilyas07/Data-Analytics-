# %% [markdown]
# # Ronaldo Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Ronaldo Goals Analysis\Data Cleaning In Python\Ronaldo_Analysis.csv')

# %%
df
# Out:
#     Season               Competition      Matchday      Date Venue  \
# 0    02/03             Liga Portugal             6  10-07-02     H
# 1    02/03             Liga Portugal             6  10-07-02     H
# 2    02/03             Liga Portugal             8  10/26/02     A
# 3    02/03  Taca de Portugal Placard  Fourth Round  11/24/02     H
# 4    02/03  Taca de Portugal Placard   Fifth Round  12/18/02     H
# ..     ...                       ...           ...       ...   ...
# 705  22/23          Saudi Pro League            16    2/9/23     A
# 706  22/23          Saudi Pro League            18   2/25/23     A
# 707  22/23          Saudi Pro League            18   2/25/23     A
# 708  22/23          Saudi Pro League            18   2/25/23     A
# 709  22/23          Saudi Pro League            21   3/18/23     H
#
#             Club                 Opponent Result Playing_Position Minute  \
# 0    Sporting CP            Moreirense FC   3:00               LW     34
# ...

# %%
df.head(10)
# Out:
#   Season               Competition      Matchday      Date Venue  \
# 0  02/03             Liga Portugal             6  10-07-02     H
# 1  02/03             Liga Portugal             6  10-07-02     H
# 2  02/03             Liga Portugal             8  10/26/02     A
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02     H
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02     H
# 5  03/04            Premier League            11  11-01-03     H
# 6  03/04                    FA Cup   Fifth Round   2/14/04     H
# 7  03/04            Premier League            29   3/20/04     H
# 8  03/04            Premier League            32  04-10-04     A
# 9  03/04            Premier League            38   5/15/04     A
#
#                 Club                 Opponent Result Playing_Position Minute  \
# 0        Sporting CP            Moreirense FC   3:00               LW     34
# 1        Sporting CP            Moreirense FC   3:00               LW   90+5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 710 entries, 0 to 709
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Season            710 non-null    object
#  1   Competition       710 non-null    object
#  2   Matchday          710 non-null    object
#  3   Date              710 non-null    object
#  4   Venue             710 non-null    object
#  5   Club              710 non-null    object
#  6   Opponent          710 non-null    object
#  7   Result            710 non-null    object
#  8   Playing_Position  652 non-null    object
#  9   Minute            710 non-null    object
#  10  At_score          710 non-null    object
#  11  Type              695 non-null    object
#  12  Goal_assist       464 non-null    object
# dtypes: object(13)
# memory usage: 72.2+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 710 entries, 0 to 709
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Season            710 non-null    object
#  1   Competition       710 non-null    object
#  2   Matchday          710 non-null    object
#  3   Date              710 non-null    object
#  4   Venue             710 non-null    object
#  5   Club              710 non-null    object
#  6   Opponent          710 non-null    object
#  7   Result            710 non-null    object
#  8   Playing_Position  652 non-null    object
#  9   Minute            710 non-null    object
#  10  At_score          710 non-null    object
#  11  Type              695 non-null    object
#  12  Goal_assist       464 non-null    object
# dtypes: object(13)
# memory usage: 72.2+ KB

# %%
df.head(10)
# Out:
#   Season               Competition      Matchday      Date Venue  \
# 0  02/03             Liga Portugal             6  10-07-02     H
# 1  02/03             Liga Portugal             6  10-07-02     H
# 2  02/03             Liga Portugal             8  10/26/02     A
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02     H
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02     H
# 5  03/04            Premier League            11  11-01-03     H
# 6  03/04                    FA Cup   Fifth Round   2/14/04     H
# 7  03/04            Premier League            29   3/20/04     H
# 8  03/04            Premier League            32  04-10-04     A
# 9  03/04            Premier League            38   5/15/04     A
#
#                 Club                 Opponent Result Playing_Position Minute  \
# 0        Sporting CP            Moreirense FC   3:00               LW     34
# 1        Sporting CP            Moreirense FC   3:00               LW   90+5
# ...

# %% [markdown]
# # Replace Venue Values

# %%
df['Venue']=df['Venue'].replace('H','Home',regex=False)
df['Venue']=df['Venue'].replace('A','Away',regex=False)

# %%
df.head(10)
# Out:
#   Season               Competition      Matchday      Date Venue  \
# 0  02/03             Liga Portugal             6  10-07-02  Home
# 1  02/03             Liga Portugal             6  10-07-02  Home
# 2  02/03             Liga Portugal             8  10/26/02  Away
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home
# 5  03/04            Premier League            11  11-01-03  Home
# 6  03/04                    FA Cup   Fifth Round   2/14/04  Home
# 7  03/04            Premier League            29   3/20/04  Home
# 8  03/04            Premier League            32  04-10-04  Away
# 9  03/04            Premier League            38   5/15/04  Away
#
#                 Club                 Opponent Result Playing_Position Minute  \
# 0        Sporting CP            Moreirense FC   3:00               LW     34
# 1        Sporting CP            Moreirense FC   3:00               LW   90+5
# ...

# %% [markdown]
# # Viewing Distinct Values In All Columns

# %%
df['Season'].unique()
# Out:
# array(['02/03', '03/04', '04/05', '05/06', '06/07', '07/08', '08/09',
#        '09/10', '10/11', '11/12', 'Dec-13', '13/14', '14/15', '15/16',
#        '16/17', '17/18', '18/19', '19/20', '20/21', '21/22', '22/23'],
#       dtype=object)

# %%
df['Competition'].unique()
# Out:
# array(['Liga Portugal', 'Taca de Portugal Placard', 'Premier League',
#        'FA Cup', 'UEFA Champions League Qualifying', 'EFL Cup',
#        'UEFA Champions League', 'FIFA Club World Cup', 'LaLiga',
#        'Copa del Rey', 'Supercopa', 'UEFA Super Cup', 'Serie A',
#        'Supercoppa Italiana', 'Italy Cup', 'Europa League',
#        'Saudi Pro League'], dtype=object)

# %%
df['Matchday'].unique()
# Out:
# array(['6', '8', 'Fourth Round', 'Fifth Round', '11', '29', '32', '38',
#        'Final', '16', 'Third Round', '24', '25', 'Sixth Round', '30',
#        'Semi-Finals', '3rd round', 'Round of 16', '20', '26', '28', '1',
#        '10', '15', '17', '19', '21', '23', '6th round', 'Quarter-Finals',
#        '37', 'Group Stage', '9', '12', '13', '18', '22', '27', 'last 16',
#        '31', '33', '34', '36', '2', '3', '4', '35', '7', '4th round',
#        '14', 'final', '5'], dtype=object)

# %%
df['Date'].unique()
# Out:
# array(['10-07-02', '10/26/02', '11/24/02', '12/18/02', '11-01-03',
#        '2/14/04', '3/20/04', '04-10-04', '5/15/04', '5/22/04', '12-04-04',
#        '1/19/05', '1/22/05', '02-01-05', '2/19/05', '03-12-05', '3/19/05',
#        '4/17/05', '08-09-05', '10/29/05', '11/30/05', '12/31/05',
#        '02-04-06', '02-11-06', '2/26/06', '03-06-06', '05-07-06',
#        '8/20/06', '9/23/06', '10/28/06', '11-04-06', '11/29/06',
#        '12-09-06', '12/23/06', '12/26/06', '12/30/06', '1/13/07',
#        '1/31/07', '02-03-07', '2/24/07', '03-10-07', '3/19/07',
#        '04-10-07', '4/14/07', '4/24/07', '05-05-07', '9/19/07', '9/29/07',
#        '10-06-07', '10/23/07', '11-03-07', '11-07-07', '11-11-07',
#        '11/27/07', '12-03-07', '12-08-07', '12/23/07', '12/26/07',
#        '12/29/07', '01-05-08', '01-12-08', '1/19/08', '1/27/08',
#        '1/30/08', '2/23/08', '03-04-08', '3/15/08', '3/19/08', '3/23/08',
#        '3/29/08', '04-01-08', '04-06-08', '4/13/08', '05-03-08',
# ...

# %%
df['Venue'].unique()
# Out:
# array(['Home', 'Away'], dtype=object)

# %%
df['Club'].unique()
# Out:
# array(['Sporting CP', 'Manchester United', 'Real Madrid', 'Juventus FC',
#        'Al-Nassr FC'], dtype=object)

# %%
df['Opponent'].unique()
# Out:
# array(['Moreirense FC', 'Boavista FC', 'CD Estarreja',
#        'FC Oliveira do Hospital', 'Portsmouth FC', 'Manchester City',
#        'Tottenham Hotspur', 'Birmingham City', 'Aston Villa',
#        'Millwall FC', 'Southampton FC', 'Exeter City', 'Arsenal FC',
#        'Everton FC', 'Fulham FC', 'Newcastle United', 'Debreceni VSC',
#        'Middlesbrough FC', 'West Bromwich Albion', 'Bolton Wanderers',
#        'Wigan Athletic', 'Charlton Athletic', 'Reading FC', 'Watford FC',
#        'AS Roma', 'AC Milan', 'Sporting CP', 'Dynamo Kyiv',
#        'Blackburn Rovers', 'Derby County', 'Sunderland AFC',
#        'West Ham United', 'Olympique Lyon', 'Liverpool FC', 'Chelsea FC',
#        'Hull City', 'Stoke City', 'Gamba Osaka', 'FC Internazionale',
#        'FC Porto', 'Deportivo de La CoruÃ±a', 'RCD Espanyol Barcelona',
#        'FC ZÃ¼rich', 'Xerez CD', 'Villarreal CF', 'Olympique Marseille',
#        'UD Almeria', 'Real Zaragoza', 'Malaga CF', 'CD Tenerife',
# ...

# %%
df['Result'].unique()
# Out:
# array(['3:00', '1:02', '4:01', '8:01', '4:02', '0:02', '3:01', '2:04',
#        '0:04', '1:00', '1:04', '1:03', '4:00', '5:01', '1:01', '0:03',
#        '3:02', '2:02', '7:01', '0:01', '2:00', '2:01', '6:00', '1:05',
#        '6:5 on pens', '4:03', '5:00', '3:05', '0:05', '5:02', '2:05',
#        '6:02', '6:01', '8:00', '2:03', '7:00', '0:1 AET', '2:06', '0:06',
#        '3:4 on pens', '2:1 AET', '1:06', '7:03', '3:04', '4:1 AET',
#        '2:08', '9:01', '10:02', '4:2 AET', '3:03', '6:03', '1:2', '3:0',
#        '2:2', '0:4', '0:3', '2:1'], dtype=object)

# %%
df['Playing_Position'].unique()
# Out:
# array(['LW', nan, 'RW', 'CF', 'LW ', 'CF '], dtype=object)

# %%
df['Playing_Position']=df['Playing_Position'].dropna()

# %%
df['Playing_Position'].unique()
# Out:
# array(['LW', nan, 'RW', 'CF', 'LW ', 'CF '], dtype=object)

# %%
df['Playing_Position'] = df['Playing_Position'].replace('nan','')

# %%
df['Playing_Position']=df['Playing_Position'].fillna('Unknown')

# %%
df['Playing_Position'].unique()
# Out:
# array(['LW', 'Unknown', 'RW', 'CF', 'LW ', 'CF '], dtype=object)

# %%
df['Minute'].unique()
# Out:
# array(['34', '90+5', '88', '67', '13', '80', '74', '89', '60', '4', '44',
#        '87', '9', '8', '54', '58', '45+1', '21', '76', '63', '90', '12',
#        '68', '14', '38', '45', '59', '23', '19', '73', '82', '10', '39',
#        '84', '85', '47', '50', '77', '49', '28', '5', '62', '51', '41',
#        '35', '90+3', '22', '81', '48', '70', '90+2', '69', '56', '79',
#        '16', '53', '3', '24', '32', '26', '25', '30', '43', '65', '11',
#        '6', '57', '61', '17', '27', '1', '75', '2', '64', '71', '18',
#        '78', '29', '36', '15', '55', '86', '90+1', '72', '20', '42',
#        '103', '46', '52', '90+4', '37', '66', '90+6', '31', '40', '120',
#        '83', '7', '33', '97', '104', '105', '109', '90+7', '45+7', '45+2'],
#       dtype=object)

# %%
df[['Minute','Extra Minute']]=df['Minute'].str.split('+',n=1,expand=True)

# %%
df.head(10)
# Out:
#   Season               Competition      Matchday      Date Venue  \
# 0  02/03             Liga Portugal             6  10-07-02  Home
# 1  02/03             Liga Portugal             6  10-07-02  Home
# 2  02/03             Liga Portugal             8  10/26/02  Away
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home
# 5  03/04            Premier League            11  11-01-03  Home
# 6  03/04                    FA Cup   Fifth Round   2/14/04  Home
# 7  03/04            Premier League            29   3/20/04  Home
# 8  03/04            Premier League            32  04-10-04  Away
# 9  03/04            Premier League            38   5/15/04  Away
#
#                 Club                 Opponent Result Playing_Position Minute  \
# 0        Sporting CP            Moreirense FC   3:00               LW     34
# 1        Sporting CP            Moreirense FC   3:00               LW     90
# ...

# %%
df['Minute'] = pd.to_numeric(df['Minute'])

# %%
df['Extra Minute'] = pd.to_numeric(df['Extra Minute'])

# %%
df.head(10)
# Out:
#   Season               Competition      Matchday      Date Venue  \
# 0  02/03             Liga Portugal             6  10-07-02  Home
# 1  02/03             Liga Portugal             6  10-07-02  Home
# 2  02/03             Liga Portugal             8  10/26/02  Away
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home
# 5  03/04            Premier League            11  11-01-03  Home
# 6  03/04                    FA Cup   Fifth Round   2/14/04  Home
# 7  03/04            Premier League            29   3/20/04  Home
# 8  03/04            Premier League            32  04-10-04  Away
# 9  03/04            Premier League            38   5/15/04  Away
#
#                 Club                 Opponent Result Playing_Position  Minute  \
# 0        Sporting CP            Moreirense FC   3:00               LW      34
# 1        Sporting CP            Moreirense FC   3:00               LW      90
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 710 entries, 0 to 709
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Season            710 non-null    object
#  1   Competition       710 non-null    object
#  2   Matchday          710 non-null    object
#  3   Date              710 non-null    object
#  4   Venue             710 non-null    object
#  5   Club              710 non-null    object
#  6   Opponent          710 non-null    object
#  7   Result            710 non-null    object
#  8   Playing_Position  710 non-null    object
#  9   Minute            710 non-null    int64
#  10  At_score          710 non-null    object
#  11  Type              695 non-null    object
#  12  Goal_assist       464 non-null    object
#  13  Extra Minute      29 non-null     float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 77.8+ KB

# %%
df['Extra Minute'] = df['Extra Minute'].fillna(0)

# %%
df['Total_Minutes_Match_Played']=df['Minute']+df['Extra Minute']

# %%
df.head()
# Out:
#   Season               Competition      Matchday      Date Venue         Club  \
# 0  02/03             Liga Portugal             6  10-07-02  Home  Sporting CP
# 1  02/03             Liga Portugal             6  10-07-02  Home  Sporting CP
# 2  02/03             Liga Portugal             8  10/26/02  Away  Sporting CP
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home  Sporting CP
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home  Sporting CP
#
#                   Opponent Result Playing_Position  Minute At_score  \
# 0            Moreirense FC   3:00               LW      34     2:00
# 1            Moreirense FC   3:00               LW      90     3:00
# 2              Boavista FC   1:02          Unknown      88     1:02
# 3             CD Estarreja   4:01          Unknown      67     3:00
# 4  FC Oliveira do Hospital   8:01          Unknown      13     3:00
#
#                 Type     Goal_assist  Extra Minute  Total_Minutes_Match_Played
# ...

# %%
df = df.drop(columns='Minute')

# %%
df=df.drop(columns='Extra Minute')

# %%
df.head(10)
# Out:
#   Season               Competition      Matchday      Date Venue  \
# 0  02/03             Liga Portugal             6  10-07-02  Home
# 1  02/03             Liga Portugal             6  10-07-02  Home
# 2  02/03             Liga Portugal             8  10/26/02  Away
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home
# 5  03/04            Premier League            11  11-01-03  Home
# 6  03/04                    FA Cup   Fifth Round   2/14/04  Home
# 7  03/04            Premier League            29   3/20/04  Home
# 8  03/04            Premier League            32  04-10-04  Away
# 9  03/04            Premier League            38   5/15/04  Away
#
#                 Club                 Opponent Result Playing_Position  \
# 0        Sporting CP            Moreirense FC   3:00               LW
# 1        Sporting CP            Moreirense FC   3:00               LW
# ...

# %%
df['Date'].unique()
# Out:
# array(['10-07-02', '10/26/02', '11/24/02', '12/18/02', '11-01-03',
#        '2/14/04', '3/20/04', '04-10-04', '5/15/04', '5/22/04', '12-04-04',
#        '1/19/05', '1/22/05', '02-01-05', '2/19/05', '03-12-05', '3/19/05',
#        '4/17/05', '08-09-05', '10/29/05', '11/30/05', '12/31/05',
#        '02-04-06', '02-11-06', '2/26/06', '03-06-06', '05-07-06',
#        '8/20/06', '9/23/06', '10/28/06', '11-04-06', '11/29/06',
#        '12-09-06', '12/23/06', '12/26/06', '12/30/06', '1/13/07',
#        '1/31/07', '02-03-07', '2/24/07', '03-10-07', '3/19/07',
#        '04-10-07', '4/14/07', '4/24/07', '05-05-07', '9/19/07', '9/29/07',
#        '10-06-07', '10/23/07', '11-03-07', '11-07-07', '11-11-07',
#        '11/27/07', '12-03-07', '12-08-07', '12/23/07', '12/26/07',
#        '12/29/07', '01-05-08', '01-12-08', '1/19/08', '1/27/08',
#        '1/30/08', '2/23/08', '03-04-08', '3/15/08', '3/19/08', '3/23/08',
#        '3/29/08', '04-01-08', '04-06-08', '4/13/08', '05-03-08',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 710 entries, 0 to 709
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Season                      710 non-null    object
#  1   Competition                 710 non-null    object
#  2   Matchday                    710 non-null    object
#  3   Date                        710 non-null    object
#  4   Venue                       710 non-null    object
#  5   Club                        710 non-null    object
#  6   Opponent                    710 non-null    object
#  7   Result                      710 non-null    object
#  8   Playing_Position            710 non-null    object
#  9   At_score                    710 non-null    object
#  10  Type                        695 non-null    object
#  11  Goal_assist                 464 non-null    object
#  12  Total_Minutes_Match_Played  710 non-null    float64
# ...

# %%
df['Date'].head(50)
# Out:
# 0     10-07-02
# 1     10-07-02
# 2     10/26/02
# 3     11/24/02
# 4     12/18/02
# 5     11-01-03
# 6      2/14/04
# 7      3/20/04
# 8     04-10-04
# 9      5/15/04
# 10     5/22/04
# 11    12-04-04
# 12     1/19/05
# 13     1/22/05
# 14    02-01-05
# 15    02-01-05
# 16     2/19/05
# 17    03-12-05
# 18     3/19/05
# 19     4/17/05
# 20    08-09-05
# 21    10/29/05
# 22    11/30/05
# 23    12/31/05
# 24    12/31/05
# 25    02-04-06
# 26    02-04-06
# 27    02-11-06
# 28    02-11-06
# 29     2/26/06
# 30    03-06-06
# 31    05-07-06
# 32     8/20/06
# 33     9/23/06
# 34    10/28/06
# 35    11-04-06
# 36    11/29/06
# 37    12-09-06
# 38    12/23/06
# 39    12/23/06
# 40    12/26/06
# 41    12/26/06
# 42    12/30/06
# 43    12/30/06
# 44     1/13/07
# 45     1/31/07
# 46    02-03-07
# 47     2/24/07
# 48    03-10-07
# 49     3/19/07
# Name: Date, dtype: object

# %%
df['Date']=df['Date'].replace('[^0-9]','/',regex=True)

# %%
df['Date'].unique()
# Out:
# array(['10/07/02', '10/26/02', '11/24/02', '12/18/02', '11/01/03',
#        '2/14/04', '3/20/04', '04/10/04', '5/15/04', '5/22/04', '12/04/04',
#        '1/19/05', '1/22/05', '02/01/05', '2/19/05', '03/12/05', '3/19/05',
#        '4/17/05', '08/09/05', '10/29/05', '11/30/05', '12/31/05',
#        '02/04/06', '02/11/06', '2/26/06', '03/06/06', '05/07/06',
#        '8/20/06', '9/23/06', '10/28/06', '11/04/06', '11/29/06',
#        '12/09/06', '12/23/06', '12/26/06', '12/30/06', '1/13/07',
#        '1/31/07', '02/03/07', '2/24/07', '03/10/07', '3/19/07',
#        '04/10/07', '4/14/07', '4/24/07', '05/05/07', '9/19/07', '9/29/07',
#        '10/06/07', '10/23/07', '11/03/07', '11/07/07', '11/11/07',
#        '11/27/07', '12/03/07', '12/08/07', '12/23/07', '12/26/07',
#        '12/29/07', '01/05/08', '01/12/08', '1/19/08', '1/27/08',
#        '1/30/08', '2/23/08', '03/04/08', '3/15/08', '3/19/08', '3/23/08',
#        '3/29/08', '04/01/08', '04/06/08', '4/13/08', '05/03/08',
# ...

# %%
df.head(10)
# Out:
#   Season               Competition      Matchday      Date Venue  \
# 0  02/03             Liga Portugal             6  10/07/02  Home
# 1  02/03             Liga Portugal             6  10/07/02  Home
# 2  02/03             Liga Portugal             8  10/26/02  Away
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home
# 5  03/04            Premier League            11  11/01/03  Home
# 6  03/04                    FA Cup   Fifth Round   2/14/04  Home
# 7  03/04            Premier League            29   3/20/04  Home
# 8  03/04            Premier League            32  04/10/04  Away
# 9  03/04            Premier League            38   5/15/04  Away
#
#                 Club                 Opponent Result Playing_Position  \
# 0        Sporting CP            Moreirense FC   3:00               LW
# 1        Sporting CP            Moreirense FC   3:00               LW
# ...

# %%
df['Goal_assist'].unique()
# Out:
# array([nan, 'Rui Jorge', 'Carlos Martins', 'Cesar Prates', 'Ryan Giggs',
#        'Gary Neville', 'Paul Scholes', 'Louis Saha',
#        'Ruud van Nistelrooy', 'Roy Keane', 'Wayne Rooney', 'John OShea',
#        'Ji-sung Park', 'Ole Gunnar Solskjaer', 'Michael Carrick',
#        'Wes Brown', 'Patrice Evra', 'Carlos Tevez', 'Nemanja Vidicâ€Ž',
#        'Nani', 'Edwin van der Sar', 'Owen Hargreaves', 'Dimitar Berbatov',
#        'Anderson', 'Guti', 'Esteban Granero', 'Pepe', 'Karim Benzema',
#        'Gonzalo Higuain', 'Lassana Diarra', 'Ezequiel Garay', 'Kaka',
#        'Marcelo', 'Sergio Ramos', 'Mesut Ozil', 'Xabi Alonso',
#        'Angel Di Maria', 'Sergio Canales', 'Sami Khedira',
#        'alvaro Arbeloa', 'Fabio CoentrÃ£o', 'Jose CallejÃ³n',
#        'Luka Modric', 'Isco', 'Gareth Bale', 'Daniel Carvajal',
#        'James Rodriguez', 'Toni Kroos', 'Chicharito', 'Lucas Vazquez',
#        'Danilo', 'Jese', 'alvaro Morata', 'Nacho Fernandez',
# ...

# %%
df['Goal_assist']=df['Goal_assist'].fillna('Not Avaliable').str.strip()

# %%
df.head(5)
# Out:
#   Season               Competition      Matchday      Date Venue         Club  \
# 0  02/03             Liga Portugal             6  10/07/02  Home  Sporting CP
# 1  02/03             Liga Portugal             6  10/07/02  Home  Sporting CP
# 2  02/03             Liga Portugal             8  10/26/02  Away  Sporting CP
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home  Sporting CP
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home  Sporting CP
#
#                   Opponent Result Playing_Position At_score  \
# 0            Moreirense FC   3:00               LW     2:00
# 1            Moreirense FC   3:00               LW     3:00
# 2              Boavista FC   1:02          Unknown     1:02
# 3             CD Estarreja   4:01          Unknown     3:00
# 4  FC Oliveira do Hospital   8:01          Unknown     3:00
#
#                 Type     Goal_assist  Total_Minutes_Match_Played
# 0           Solo run   Not Avaliable                        34.0
# ...

# %%
df = df.drop(columns='At_score')

# %%
df.head(5)
# Out:
#   Season               Competition      Matchday      Date Venue         Club  \
# 0  02/03             Liga Portugal             6  10/07/02  Home  Sporting CP
# 1  02/03             Liga Portugal             6  10/07/02  Home  Sporting CP
# 2  02/03             Liga Portugal             8  10/26/02  Away  Sporting CP
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home  Sporting CP
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home  Sporting CP
#
#                   Opponent Result Playing_Position               Type  \
# 0            Moreirense FC   3:00               LW           Solo run
# 1            Moreirense FC   3:00               LW             Header
# 2              Boavista FC   1:02          Unknown  Right-footed shot
# 3             CD Estarreja   4:01          Unknown   Left-footed shot
# 4  FC Oliveira do Hospital   8:01          Unknown                NaN
#
#       Goal_assist  Total_Minutes_Match_Played
# ...

# %%
df[['Ronaldo Team Goals','Opponent Team Goals']] = df['Result'].str.split(':',n=1,expand=True)

# %%
df.head(5)
# Out:
#   Season               Competition      Matchday      Date Venue         Club  \
# 0  02/03             Liga Portugal             6  10/07/02  Home  Sporting CP
# 1  02/03             Liga Portugal             6  10/07/02  Home  Sporting CP
# 2  02/03             Liga Portugal             8  10/26/02  Away  Sporting CP
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home  Sporting CP
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home  Sporting CP
#
#                   Opponent Result Playing_Position               Type  \
# 0            Moreirense FC   3:00               LW           Solo run
# 1            Moreirense FC   3:00               LW             Header
# 2              Boavista FC   1:02          Unknown  Right-footed shot
# 3             CD Estarreja   4:01          Unknown   Left-footed shot
# 4  FC Oliveira do Hospital   8:01          Unknown                NaN
#
#       Goal_assist  Total_Minutes_Match_Played Ronaldo Team Goals  \
# ...

# %%
df['Season'].count()
# Out:
# np.int64(710)

# %%
df.head(10)
# Out:
#   Season               Competition      Matchday      Date Venue  \
# 0  02/03             Liga Portugal             6  10/07/02  Home
# 1  02/03             Liga Portugal             6  10/07/02  Home
# 2  02/03             Liga Portugal             8  10/26/02  Away
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home
# 5  03/04            Premier League            11  11/01/03  Home
# 6  03/04                    FA Cup   Fifth Round   2/14/04  Home
# 7  03/04            Premier League            29   3/20/04  Home
# 8  03/04            Premier League            32  04/10/04  Away
# 9  03/04            Premier League            38   5/15/04  Away
#
#                 Club                 Opponent Result Playing_Position  \
# 0        Sporting CP            Moreirense FC   3:00               LW
# 1        Sporting CP            Moreirense FC   3:00               LW
# ...

# %%
df = df.rename(columns={'Result':'Match_Result'})

# %%
df.head(5)
# Out:
#   Season               Competition      Matchday      Date Venue         Club  \
# 0  02/03             Liga Portugal             6  10/07/02  Home  Sporting CP
# 1  02/03             Liga Portugal             6  10/07/02  Home  Sporting CP
# 2  02/03             Liga Portugal             8  10/26/02  Away  Sporting CP
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home  Sporting CP
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home  Sporting CP
#
#                   Opponent Match_Result Playing_Position               Type  \
# 0            Moreirense FC         3:00               LW           Solo run
# 1            Moreirense FC         3:00               LW             Header
# 2              Boavista FC         1:02          Unknown  Right-footed shot
# 3             CD Estarreja         4:01          Unknown   Left-footed shot
# 4  FC Oliveira do Hospital         8:01          Unknown                NaN
#
# ...

# %%
df['Type']=df['Type'].fillna('Unknown')

# %%
df.head(5)
# Out:
#   Season               Competition      Matchday      Date Venue         Club  \
# 0  02/03             Liga Portugal             6  10/07/02  Home  Sporting CP
# 1  02/03             Liga Portugal             6  10/07/02  Home  Sporting CP
# 2  02/03             Liga Portugal             8  10/26/02  Away  Sporting CP
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home  Sporting CP
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home  Sporting CP
#
#                   Opponent Match_Result Playing_Position               Type  \
# 0            Moreirense FC         3:00               LW           Solo run
# 1            Moreirense FC         3:00               LW             Header
# 2              Boavista FC         1:02          Unknown  Right-footed shot
# 3             CD Estarreja         4:01          Unknown   Left-footed shot
# 4  FC Oliveira do Hospital         8:01          Unknown            Unknown
#
# ...

# %%
df['Matchday'].unique()
# Out:
# array(['6', '8', 'Fourth Round', 'Fifth Round', '11', '29', '32', '38',
#        'Final', '16', 'Third Round', '24', '25', 'Sixth Round', '30',
#        'Semi-Finals', '3rd round', 'Round of 16', '20', '26', '28', '1',
#        '10', '15', '17', '19', '21', '23', '6th round', 'Quarter-Finals',
#        '37', 'Group Stage', '9', '12', '13', '18', '22', '27', 'last 16',
#        '31', '33', '34', '36', '2', '3', '4', '35', '7', '4th round',
#        '14', 'final', '5'], dtype=object)

# %%
group_mapping = {
    '1': 'Early Rounds',
    '2': 'Early Rounds',
    '3': 'Early Rounds',
    '4': 'Early Rounds',
    '5': 'Early Rounds',
    '6': 'Early Rounds',
    '7': 'Early Rounds',
    '8': 'Early Rounds',
    '9': 'Early Rounds',
    '10': 'Early Rounds',
    '11': 'Early Rounds',
    '12': 'Early Rounds',
    '13': 'Early Rounds',
    '14': 'Early Rounds',
    '15': 'Early Rounds',
    '16': 'Early Rounds',
    '17': 'Early Rounds',
    '18': 'Early Rounds',
    '19': 'Early Rounds',
    '20': 'Early Rounds',
    '21': 'Early Rounds',
    '22': 'Early Rounds',
    '23': 'Early Rounds',
    '24': 'Early Rounds',
    '25': 'Early Rounds',
    '26': 'Early Rounds',
    '27': 'Early Rounds',
    '28': 'Early Rounds',
    '29': 'Early Rounds',
    '30': 'Early Rounds',
    '31': 'Early Rounds',
    '32': 'Early Rounds',
    '33': 'Early Rounds',
    '34': 'Early Rounds',
    '35': 'Early Rounds',
    '36': 'Early Rounds',
    '37': 'Early Rounds',
    '38': 'Early Rounds',
    'Group Stage': 'Group Stage',
    'Final': 'Final',
    'Semi-Finals': 'Semi-Finals',
    'Quarter-Finals': 'Quarter-Finals',
    'Round of 16': 'Round of 16',
    'Third Round': 'Third Round',
    'Fourth Round': 'Fourth Round',
    'Fifth Round': 'Fifth Round',
    'Sixth Round': 'Sixth Round',
    'last 16': 'Last 16',
    'final': 'Final',
    '3rd round': 'Third Round',
    '4th round': 'Fourth Round',
    '6th round': 'Sixth Round',
}

# Replace values in the 'Matchday' column using the mapping dictionary
df['Matchday'] = df['Matchday'].replace(group_mapping)

df.head(5)
# Out:
#   Season               Competition      Matchday      Date Venue         Club  \
# 0  02/03             Liga Portugal  Early Rounds  10/07/02  Home  Sporting CP
# 1  02/03             Liga Portugal  Early Rounds  10/07/02  Home  Sporting CP
# 2  02/03             Liga Portugal  Early Rounds  10/26/02  Away  Sporting CP
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home  Sporting CP
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home  Sporting CP
#
#                   Opponent Match_Result Playing_Position               Type  \
# 0            Moreirense FC         3:00               LW           Solo run
# 1            Moreirense FC         3:00               LW             Header
# 2              Boavista FC         1:02          Unknown  Right-footed shot
# 3             CD Estarreja         4:01          Unknown   Left-footed shot
# 4  FC Oliveira do Hospital         8:01          Unknown            Unknown
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 710 entries, 0 to 709
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Season                      710 non-null    object
#  1   Competition                 710 non-null    object
#  2   Matchday                    710 non-null    object
#  3   Date                        710 non-null    object
#  4   Venue                       710 non-null    object
#  5   Club                        710 non-null    object
#  6   Opponent                    710 non-null    object
#  7   Match_Result                710 non-null    object
#  8   Playing_Position            710 non-null    object
#  9   Type                        710 non-null    object
#  10  Goal_assist                 710 non-null    object
#  11  Total_Minutes_Match_Played  710 non-null    float64
#  12  Ronaldo Team Goals          710 non-null    object
# ...

# %% [markdown]
# # Till here my Data is Fully Cleaned

# %% [markdown]
# Seperated Columns Replaced null values Made Date format Correct ETC Now Export Csv

# %%
df.to_csv('E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Ronaldo_Cleaned.csv',index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_9724\3566243204.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df.to_csv('E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Ronaldo_Cleaned.csv',index=False)

# %%
df['Match_Result'] = df['Match_Result'].astype('str')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 710 entries, 0 to 709
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Season                      710 non-null    object
#  1   Competition                 710 non-null    object
#  2   Matchday                    710 non-null    object
#  3   Date                        710 non-null    object
#  4   Venue                       710 non-null    object
#  5   Club                        710 non-null    object
#  6   Opponent                    710 non-null    object
#  7   Match_Result                710 non-null    object
#  8   Playing_Position            710 non-null    object
#  9   Type                        710 non-null    object
#  10  Goal_assist                 710 non-null    object
#  11  Total_Minutes_Match_Played  710 non-null    float64
#  12  Ronaldo Team Goals          710 non-null    object
# ...

# %%
df['Match_Result']=df['Match_Result'].str.replace(':','-')

# %%
df
# Out:
#     Season               Competition      Matchday      Date Venue  \
# 0    02/03             Liga Portugal  Early Rounds  10/07/02  Home
# 1    02/03             Liga Portugal  Early Rounds  10/07/02  Home
# 2    02/03             Liga Portugal  Early Rounds  10/26/02  Away
# 3    02/03  Taca de Portugal Placard  Fourth Round  11/24/02  Home
# 4    02/03  Taca de Portugal Placard   Fifth Round  12/18/02  Home
# ..     ...                       ...           ...       ...   ...
# 705  22/23          Saudi Pro League  Early Rounds    2/9/23  Away
# 706  22/23          Saudi Pro League  Early Rounds   2/25/23  Away
# 707  22/23          Saudi Pro League  Early Rounds   2/25/23  Away
# 708  22/23          Saudi Pro League  Early Rounds   2/25/23  Away
# 709  22/23          Saudi Pro League  Early Rounds   3/18/23  Home
#
#             Club                 Opponent Match_Result Playing_Position  \
# 0    Sporting CP            Moreirense FC         3-00               LW
# ...

# %%
df['Goal_assist'] = df['Goal_assist'].str.replace('Not Avaliable','Unknown')

# %%
df.to_excel('E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Ronaldo Goals Analysis\RonaldoAnalysis.xlsx',index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_9724\3060701464.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df.to_excel('E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Ronaldo Goals Analysis\RonaldoAnalysis.xlsx',index=False)

# %%
df.to_csv('E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Ronaldo Goals Analysis\RonaldoAnalysis.csv',index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_9724\1628389712.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df.to_csv('E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Ronaldo Goals Analysis\RonaldoAnalysis.csv',index=False)
