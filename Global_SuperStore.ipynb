# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Global Superstore Dataset\Analysis and Cleaning in Python\Global_Superstore2.csv',encoding='latin1')

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
pd.set_option('display.max.columns',24)

# %%
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  \
# 0       Rick Hansen     Consumer  New York City         New York
# 1     Justin Ritter    Corporate     Wollongong  New South Wales
# 2      Craig Reiter     Consumer       Brisbane       Queensland
# 3  Katherine Murray  Home Office         Berlin           Berlin
# 4       Rick Hansen     Consumer          Dakar            Dakar
#
#          Country  Postal Code  Market   Region        Product ID    Category  \
# ...

# %%
df['Order ID']=df['Order ID'].str.strip()

# %% [markdown]
# # Fixing Column Names

# %%
df.rename(columns={'Order Date':'Order_Date'},inplace=True)

# %%
df.rename(columns={'Order ID':'Order_ID','Ship Date':'Ship_Date','Ship Mode':'Ship_Mode','Customer ID':'Customer_ID','Customer Name':'Customer_Name','Postal Code':'Postal_Code','Product ID':'Product_ID','Product Name':'Product_Name','Shipping Cost':'Shipping_Cost','Order Priority':'Order_Priority'},inplace=True)

# %% [markdown]
# # Fixing Order_Date and Ship_Date Column Format

# %%
df['Order_Date']
df['Ship_Date']
# Out:
# 0        31-07-2012
# 1        07-02-2013
# 2        18-10-2013
# 3        30-01-2013
# 4        06-11-2013
#             ...
# 51285    19-06-2014
# 51286    24-06-2014
# 51287    02-12-2013
# 51288    22-02-2012
# 51289    26-05-2012
# Name: Ship_Date, Length: 51290, dtype: object

# %%
df['Order_Date']=df['Order_Date'].str.replace('[^0-9]','',regex=True)
df['Ship_Date']=df['Ship_Date'].str.replace('[^0-9]','',regex=True)

# %%
df.head()
# Out:
#    Row ID         Order_ID Order_Date Ship_Date     Ship_Mode Customer_ID  \
# 0   32298   CA-2012-124891   31072012  31072012      Same Day    RH-19495
# 1   26341    IN-2013-77878   05022013  07022013  Second Class    JR-16210
# 2   25330    IN-2013-71249   17102013  18102013   First Class    CR-12730
# 3   13524  ES-2013-1579342   28012013  30012013   First Class    KM-16375
# 4   47221     SG-2013-4320   05112013  06112013      Same Day     RH-9495
#
#       Customer_Name      Segment           City            State  \
# 0       Rick Hansen     Consumer  New York City         New York
# 1     Justin Ritter    Corporate     Wollongong  New South Wales
# 2      Craig Reiter     Consumer       Brisbane       Queensland
# 3  Katherine Murray  Home Office         Berlin           Berlin
# 4       Rick Hansen     Consumer          Dakar            Dakar
#
#          Country  Postal_Code  Market   Region        Product_ID    Category  \
# ...

# %%
df['Order_Date']=df['Order_Date'].apply(lambda x : x[0:2]+'/'+x[2:4]+'/'+x[4:9])
df['Ship_Date']=df['Ship_Date'].apply(lambda x : x[0:2]+'/'+x[2:4]+'/'+x[4:9])

# %%
df.head(3)
# Out:
#    Row ID        Order_ID  Order_Date   Ship_Date     Ship_Mode Customer_ID  \
# 0   32298  CA-2012-124891  31/07/2012  31/07/2012      Same Day    RH-19495
# 1   26341   IN-2013-77878  05/02/2013  07/02/2013  Second Class    JR-16210
# 2   25330   IN-2013-71249  17/10/2013  18/10/2013   First Class    CR-12730
#
#    Customer_Name    Segment           City            State        Country  \
# 0    Rick Hansen   Consumer  New York City         New York  United States
# 1  Justin Ritter  Corporate     Wollongong  New South Wales      Australia
# 2   Craig Reiter   Consumer       Brisbane       Queensland      Australia
#
#    Postal_Code Market   Region       Product_ID    Category Sub-Category  \
# 0      10024.0     US     East  TEC-AC-10003033  Technology  Accessories
# 1          NaN   APAC  Oceania  FUR-CH-10003950   Furniture       Chairs
# 2          NaN   APAC  Oceania  TEC-PH-10004664  Technology       Phones
#
# ...

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Postal_Code']=df['Postal_Code'].fillna('')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order_ID        51290 non-null  object
#  2   Order_Date      51290 non-null  object
#  3   Ship_Date       51290 non-null  object
#  4   Ship_Mode       51290 non-null  object
#  5   Customer_ID     51290 non-null  object
#  6   Customer_Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal_Code     51290 non-null  object
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product_ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %% [markdown]
# # Data is Cleaned now it's time to Analyze

# %%
df.head(3)
# Out:
#    Row ID        Order_ID  Order_Date   Ship_Date     Ship_Mode Customer_ID  \
# 0   32298  CA-2012-124891  31/07/2012  31/07/2012      Same Day    RH-19495
# 1   26341   IN-2013-77878  05/02/2013  07/02/2013  Second Class    JR-16210
# 2   25330   IN-2013-71249  17/10/2013  18/10/2013   First Class    CR-12730
#
#    Customer_Name    Segment           City            State        Country  \
# 0    Rick Hansen   Consumer  New York City         New York  United States
# 1  Justin Ritter  Corporate     Wollongong  New South Wales      Australia
# 2   Craig Reiter   Consumer       Brisbane       Queensland      Australia
#
#   Postal_Code Market   Region       Product_ID    Category Sub-Category  \
# 0     10024.0     US     East  TEC-AC-10003033  Technology  Accessories
# 1               APAC  Oceania  FUR-CH-10003950   Furniture       Chairs
# 2               APAC  Oceania  TEC-PH-10004664  Technology       Phones
#
# ...

# %% [markdown]
# # Statistical Portion

# %%
df.describe()
# Out:
#             Row ID         Sales      Quantity      Discount        Profit  \
# count  51290.00000  51290.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000    246.490581      3.476545      0.142908     28.610982
# std    14806.29199    487.565361      2.278766      0.212280    174.340972
# min        1.00000      0.444000      1.000000      0.000000  -6599.978000
# 25%    12823.25000     30.758625      2.000000      0.000000      0.000000
# 50%    25645.50000     85.053000      3.000000      0.000000      9.240000
# 75%    38467.75000    251.053200      5.000000      0.200000     36.810000
# max    51290.00000  22638.480000     14.000000      0.850000   8399.976000
#
#        Shipping_Cost
# count   51290.000000
# mean       26.375915
# std        57.296804
# min         0.000000
# 25%         2.610000
# 50%         7.790000
# 75%        24.450000
# max       933.570000

# %%
x = df.corr(numeric_only=True)

# %%
sns.heatmap(x)
# Out:
# <Axes: >

# %% [markdown]
# # KPI's

# %%
df.head(3)
# Out:
#    Row ID        Order_ID  Order_Date   Ship_Date     Ship_Mode Customer_ID  \
# 0   32298  CA-2012-124891  31/07/2012  31/07/2012      Same Day    RH-19495
# 1   26341   IN-2013-77878  05/02/2013  07/02/2013  Second Class    JR-16210
# 2   25330   IN-2013-71249  17/10/2013  18/10/2013   First Class    CR-12730
#
#    Customer_Name    Segment           City            State        Country  \
# 0    Rick Hansen   Consumer  New York City         New York  United States
# 1  Justin Ritter  Corporate     Wollongong  New South Wales      Australia
# 2   Craig Reiter   Consumer       Brisbane       Queensland      Australia
#
#   Postal_Code Market   Region       Product_ID    Category Sub-Category  \
# 0     10024.0     US     East  TEC-AC-10003033  Technology  Accessories
# 1               APAC  Oceania  FUR-CH-10003950   Furniture       Chairs
# 2               APAC  Oceania  TEC-PH-10004664  Technology       Phones
#
# ...

# %%
# Total Orders
df['Order_ID'].count()
# Out:
# np.int64(51290)

# %%
# Total Sales 
df['Sales'].sum()
# Out:
# np.float64(12642501.909880001)

# %%
# Total Quantity Sold
df['Quantity'].sum()
# Out:
# np.int64(178312)

# %%
# Total Profit
df['Profit'].sum()
# Out:
# np.float64(1467457.29128)

# %%
# Average Order Value
(df['Sales'].sum())/(df['Order_ID'].count())
# Out:
# np.float64(246.49058120257362)

# %%
# Profit Margin
(df['Profit'].sum())/(df['Sales'].sum())*100  # 11 Percent Profit
# Out:
# np.float64(11.607332960995603)

# %%
df.groupby('Order_Date').agg({'Order_ID':'count','Sales':'sum'}).sort_values(by='Order_Date',ascending=True).head(10).plot()
# Out:
# <Axes: xlabel='Order_Date'>

# %%
df.head()
# Out:
#    Row ID         Order_ID  Order_Date   Ship_Date     Ship_Mode Customer_ID  \
# 0   32298   CA-2012-124891  31/07/2012  31/07/2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05/02/2013  07/02/2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17/10/2013  18/10/2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28/01/2013  30/01/2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05/11/2013  06/11/2013      Same Day     RH-9495
#
#       Customer_Name      Segment           City            State  \
# 0       Rick Hansen     Consumer  New York City         New York
# 1     Justin Ritter    Corporate     Wollongong  New South Wales
# 2      Craig Reiter     Consumer       Brisbane       Queensland
# 3  Katherine Murray  Home Office         Berlin           Berlin
# 4       Rick Hansen     Consumer          Dakar            Dakar
#
#          Country Postal_Code  Market   Region        Product_ID    Category  \
# ...

# %%
df['Ship_Mode'].value_counts().plot(color='Orange')
# Out:
# <Axes: xlabel='Ship_Mode'>

# %%
df['Segment'].value_counts().plot(kind='bar',color='Orange')
# Out:
# <Axes: xlabel='Segment'>

# %%
df['City'].value_counts().plot()
# Out:
# <Axes: xlabel='City'>

# %%
df['Market'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# Most Profitable Product 
df.groupby('Product_Name').agg({'Profit':'sum'}).sort_values(by='Profit',ascending=False).head(10)
# Out:
#                                                         Profit
# Product_Name
# Canon imageCLASS 2200 Advanced Copier               25199.9280
# Cisco Smart Phone, Full Size                        17238.5206
# Motorola Smart Phone, Full Size                     17027.1130
# Hoover Stove, Red                                   11807.9690
# Sauder Classic Bookcase, Traditional                10672.0730
# Harbour Creations Executive Leather Armchair, A...  10427.3260
# Nokia Smart Phone, Full Size                         9938.1955
# Cisco Smart Phone, with Caller ID                    9786.6408
# Nokia Smart Phone, with Caller ID                    9465.3257
# Belkin Router, USB                                   8955.0180

# %%
df['Product_Name'].value_counts().head(10)
# Out:
# Product_Name
# Staples                                  227
# Cardinal Index Tab, Clear                 92
# Eldon File Cart, Single Width             90
# Rogers File Cart, Single Width            84
# Ibico Index Tab, Clear                    83
# Sanford Pencil Sharpener, Water Color     80
# Smead File Cart, Single Width             77
# Acco Index Tab, Clear                     75
# Stanley Pencil Sharpener, Water Color     75
# Avery Index Tab, Clear                    74
# Name: count, dtype: int64

# %%
df.to_excel(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Global Superstore Dataset\Analysis and Cleaning in Python\cleanedStore.xlsx',index=False)

# %%
df['Order_Date']=df['Order_Date'].replace('/','-',regex=True)

# %%
df['Order_Date']=pd.to_datetime(df['Order_Date'])
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_7088\1882151666.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Order_Date']=pd.to_datetime(df['Order_Date'])

# %%
df.to_excel(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Different Analysis\Global Superstore Dataset\Analysis and Cleaning in Python\Cleaned_Store.xlsx',index=False)

# %%
df[df['Customer_ID']=='RH-19495']
# Out:
#        Row ID         Order_ID Order_Date   Ship_Date       Ship_Mode  \
# 0       32298   CA-2012-124891 2012-07-31  31/07/2012        Same Day
# 331     32299   CA-2012-124891 2012-07-31  31/07/2012        Same Day
# 2069     9345   US-2013-116771 2013-05-01  01/05/2013        Same Day
# 3424    12338  ES-2013-5957121 2013-09-14  15/09/2013     First Class
# 3439     4695   MX-2014-135069 2014-10-14  19/10/2014  Standard Class
# 3551    12337  ES-2013-5957121 2013-09-14  15/09/2013     First Class
# 3995    19778  ES-2014-2769035 2014-01-06  10/01/2014  Standard Class
# 6621    19777  ES-2014-2769035 2014-01-06  10/01/2014  Standard Class
# 6955    29350    IN-2012-13961 2012-06-25  29/06/2012  Standard Class
# 7137    20538    IN-2011-37481 2011-05-02  05/05/2011    Second Class
# 7754     5027   US-2014-117282 2014-11-30  05/12/2014    Second Class
# 7937    30976    ID-2013-86971 2013-06-13  19/06/2013  Standard Class
# ...
