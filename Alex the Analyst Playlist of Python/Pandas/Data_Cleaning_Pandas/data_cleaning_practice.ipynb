# %%
import pandas as pd

# %%
df = pd.read_excel(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Python\Alex the Analyst Playlist of Python\Pandas\Data_Cleaning_Pandas\Customer Call List.xlsx')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Last_Name']=df['Last_Name'].str.strip('/..._')
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\3518164042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Last_Name']=df['Last_Name'].str.strip('/..._')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].replace('[^a-zA-Z0-9]','',regex=True)
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\2398693993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number'] = df['Phone_Number'].replace('[^a-zA-Z0-9]','',regex=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          NaN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          NaN
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].astype('str')
df['Phone_Number'] = df['Phone_Number'].apply(lambda x : x [0:3] + '-' + x[3:6] + '-' + x[6:10])
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\226774194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number'] = df['Phone_Number'].astype('str')
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\226774194.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number'] = df['Phone_Number'].apply(lambda x : x [0:3] + '-' + x[3:6] + '-' + x[6:10])

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger         nan--
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN          Na--
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee         nan--
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
df['Phone_Number']=df['Phone_Number'].str.replace('nan--','')
df['Phone_Number']=df['Phone_Number'].str.replace('Na--','')
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\3152428507.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number']=df['Phone_Number'].str.replace('nan--','')
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\3152428507.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number']=df['Phone_Number'].str.replace('Na--','')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
df[['Address','State','StreetNo']]=df['Address'].str.split(',',n=2,expand=True)
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\4161103064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Address','State','StreetNo']]=df['Address'].str.split(',',n=2,expand=True)
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\4161103064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Address','State','StreetNo']]=df['Address'].str.split(',',n=2,expand=True)
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White  706-695-0392    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN                    123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee                      612 Shire Lane
# 11        1012      Harry      Potter  706-695-0392  2394 Hogwarts Avenue
# ...

# %%
df.drop(columns='Address')
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123-643-9775              No
# 2         1003     Walter       White  706-695-0392               N
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876-678-3469               Y
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger                            No
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 8         1009    Gandalf         NaN                           Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee                           Yes
# 11        1012      Harry      Potter  706-695-0392               Y
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
df.drop(columns='Not_Useful_Column')
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White  706-695-0392    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN                    123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee                      612 Shire Lane
# 11        1012      Harry      Potter  706-695-0392  2394 Hogwarts Avenue
# ...

# %%
df['Paying Customer']=df['Paying Customer'].replace('Y','Yes',regex=False)
df['Paying Customer']=df['Paying Customer'].replace('N','No',regex=False)
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\1003152577.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer']=df['Paying Customer'].replace('Y','Yes',regex=False)
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\1003152577.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer']=df['Paying Customer'].replace('N','No',regex=False)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White  706-695-0392    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN                    123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee                      612 Shire Lane
# 11        1012      Harry      Potter  706-695-0392  2394 Hogwarts Avenue
# ...

# %%
df['Do_Not_Contact']=df['Do_Not_Contact'].replace('Y','Yes',regex=False)
df['Do_Not_Contact']=df['Do_Not_Contact'].replace('N','No',regex=False)
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\3075094803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Do_Not_Contact']=df['Do_Not_Contact'].replace('Y','Yes',regex=False)
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\3075094803.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Do_Not_Contact']=df['Do_Not_Contact'].replace('N','No',regex=False)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White  706-695-0392    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN                    123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee                      612 Shire Lane
# 11        1012      Harry      Potter  706-695-0392  2394 Hogwarts Avenue
# ...

# %%
df.drop(columns='Address',inplace=True)
df.drop(columns='Not_Useful_Column',inplace=True)
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\3059674459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns='Address',inplace=True)
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\3059674459.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns='Not_Useful_Column',inplace=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123-643-9775              No
# 2         1003     Walter       White  706-695-0392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876-678-3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger                            No
# 7         1008   Sherlock      Holmes  876-678-3469              No
# 8         1009    Gandalf         NaN                           Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee                           Yes
# 11        1012      Harry      Potter  706-695-0392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
df['Paying Customer'] = df['Paying Customer'].str.replace('N/a','',regex=False)
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\2026068100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer'] = df['Paying Customer'].str.replace('N/a','',regex=False)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123-643-9775              No
# 2         1003     Walter       White  706-695-0392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876-678-3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger                            No
# 7         1008   Sherlock      Holmes  876-678-3469              No
# 8         1009    Gandalf         NaN                           Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee                           Yes
# 11        1012      Harry      Potter  706-695-0392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
for x in df.index:
    if df.loc[x,'Phone_Number'] == '':
        df.drop(x,inplace=True)
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\694760483.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(x,inplace=True)
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\694760483.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(x,inplace=True)
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\694760483.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123-643-9775              No
# 2         1003     Walter       White  706-695-0392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876-678-3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 7         1008   Sherlock      Holmes  876-678-3469              No
# 9         1010      Peter      Parker  123-545-5421             Yes
# 11        1012      Harry      Potter  706-695-0392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876-678-3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# 15        1016        Ron     Weasley  123-545-5421              No
# ...

# %%
for x in df.index:
    if df.loc[x,'Do_Not_Contact'] == 'Yes':
        df.drop(x,inplace=True)
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\3106927570.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(x,inplace=True)
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\3106927570.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(x,inplace=True)
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\3106927570.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 2         1003     Walter       White  706-695-0392              No
# 4         1005        Jon        Snow  876-678-3469             Yes
# 7         1008   Sherlock      Holmes  876-678-3469              No
# 9         1010      Peter      Parker  123-545-5421             Yes
# 11        1012      Harry      Potter  706-695-0392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876-678-3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123-643-9775             Yes
# 17        1018      Clark        Kent  706-695-0392             Yes
# 19        1020     Anakin   Skywalker  876-678-3469             Yes
#
# ...

# %%
df.reset_index(drop=True)
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1003     Walter       White  706-695-0392              No
# 2         1005        Jon        Snow  876-678-3469             Yes
# 3         1008   Sherlock      Holmes  876-678-3469              No
# 4         1010      Peter      Parker  123-545-5421             Yes
# 5         1012      Harry      Potter  706-695-0392             Yes
# 6         1013        Don      Draper  123-543-2345             Yes
# 7         1014     Leslie       Knope  876-678-3469             Yes
# 8         1015       Toby  Flenderson  304-762-2467              No
# 9         1016        Ron     Weasley  123-545-5421              No
# 10        1017   Michael        Scott  123-643-9775             Yes
# 11        1018      Clark        Kent  706-695-0392             Yes
# 12        1020     Anakin   Skywalker  876-678-3469             Yes
#
# ...

# %%
df.fillna('')
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 2         1003     Walter       White  706-695-0392              No
# 4         1005        Jon        Snow  876-678-3469             Yes
# 7         1008   Sherlock      Holmes  876-678-3469              No
# 9         1010      Peter      Parker  123-545-5421             Yes
# 11        1012      Harry      Potter  706-695-0392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876-678-3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123-643-9775             Yes
# 17        1018      Clark        Kent  706-695-0392             Yes
# 19        1020     Anakin   Skywalker  876-678-3469             Yes
#
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 2         1003     Walter       White  706-695-0392              No
# 4         1005        Jon        Snow  876-678-3469             Yes
# 7         1008   Sherlock      Holmes  876-678-3469              No
# 9         1010      Peter      Parker  123-545-5421             Yes
# 11        1012      Harry      Potter  706-695-0392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876-678-3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123-643-9775             Yes
# 17        1018      Clark        Kent  706-695-0392             Yes
# 19        1020     Anakin   Skywalker  876-678-3469             Yes
#
# ...

# %%
df.fillna('',inplace=True)
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\3094999256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna('',inplace=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 2         1003     Walter       White  706-695-0392              No
# 4         1005        Jon        Snow  876-678-3469             Yes
# 7         1008   Sherlock      Holmes  876-678-3469              No
# 9         1010      Peter      Parker  123-545-5421             Yes
# 11        1012      Harry      Potter  706-695-0392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876-678-3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123-643-9775             Yes
# 17        1018      Clark        Kent  706-695-0392             Yes
# 19        1020     Anakin   Skywalker  876-678-3469             Yes
#
# ...

# %%
df.dropna()
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 2         1003     Walter       White  706-695-0392              No
# 4         1005        Jon        Snow  876-678-3469             Yes
# 7         1008   Sherlock      Holmes  876-678-3469              No
# 9         1010      Peter      Parker  123-545-5421             Yes
# 11        1012      Harry      Potter  706-695-0392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876-678-3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123-643-9775             Yes
# 17        1018      Clark        Kent  706-695-0392             Yes
# 19        1020     Anakin   Skywalker  876-678-3469             Yes
#
# ...

# %%
for x in df.index:
    if df.loc[x,'Do_Not_Contact'] == '':
        df.drop(x,inplace=True)

df
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\1642143780.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(x,inplace=True)
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\1642143780.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(x,inplace=True)
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\1642143780.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    index  CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0      0        1001      Frodo     Baggins  123-545-5421             Yes
# 1      4        1005        Jon        Snow  876-678-3469             Yes
# 2      7        1008   Sherlock      Holmes  876-678-3469              No
# 3      9        1010      Peter      Parker  123-545-5421             Yes
# 4     12        1013        Don      Draper  123-543-2345             Yes
# 5     13        1014     Leslie       Knope  876-678-3469             Yes
# 6     14        1015       Toby  Flenderson  304-762-2467              No
# 7     15        1016        Ron     Weasley  123-545-5421              No
# 8     16        1017   Michael        Scott  123-643-9775             Yes
# 9     19        1020     Anakin   Skywalker  876-678-3469             Yes
#
#   Do_Not_Contact          State StreetNo
# 0             No          Shire
# 1             No
# 2             No
# 3             No       New York
# ...

# %%
df.drop(columns='StreetNo',inplace= True)
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\2731539076.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns='StreetNo',inplace= True)

# %%
df
# Out:
#    index  CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0      0        1001      Frodo     Baggins  123-545-5421             Yes
# 1      4        1005        Jon        Snow  876-678-3469             Yes
# 2      7        1008   Sherlock      Holmes  876-678-3469              No
# 3      9        1010      Peter      Parker  123-545-5421             Yes
# 4     12        1013        Don      Draper  123-543-2345             Yes
# 5     13        1014     Leslie       Knope  876-678-3469             Yes
# 6     14        1015       Toby  Flenderson  304-762-2467              No
# 7     15        1016        Ron     Weasley  123-545-5421              No
# 8     16        1017   Michael        Scott  123-643-9775             Yes
# 9     19        1020     Anakin   Skywalker  876-678-3469             Yes
#
#   Do_Not_Contact          State
# 0             No          Shire
# 1             No
# 2             No
# 3             No       New York
# 4             No
# ...

# %%
df.reset_index(drop=True)
# Out:
#    index  CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0      0        1001      Frodo     Baggins  123-545-5421             Yes
# 1      4        1005        Jon        Snow  876-678-3469             Yes
# 2      7        1008   Sherlock      Holmes  876-678-3469              No
# 3      9        1010      Peter      Parker  123-545-5421             Yes
# 4     12        1013        Don      Draper  123-543-2345             Yes
# 5     13        1014     Leslie       Knope  876-678-3469             Yes
# 6     14        1015       Toby  Flenderson  304-762-2467              No
# 7     15        1016        Ron     Weasley  123-545-5421              No
# 8     16        1017   Michael        Scott  123-643-9775             Yes
# 9     19        1020     Anakin   Skywalker  876-678-3469             Yes
#
#   Do_Not_Contact          State
# 0             No          Shire
# 1             No
# 2             No
# 3             No       New York
# 4             No
# ...

# %%
df
# Out:
#    index  CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0      0        1001      Frodo     Baggins  123-545-5421             Yes
# 1      4        1005        Jon        Snow  876-678-3469             Yes
# 2      7        1008   Sherlock      Holmes  876-678-3469              No
# 3      9        1010      Peter      Parker  123-545-5421             Yes
# 4     12        1013        Don      Draper  123-543-2345             Yes
# 5     13        1014     Leslie       Knope  876-678-3469             Yes
# 6     14        1015       Toby  Flenderson  304-762-2467              No
# 7     15        1016        Ron     Weasley  123-545-5421              No
# 8     16        1017   Michael        Scott  123-643-9775             Yes
# 9     19        1020     Anakin   Skywalker  876-678-3469             Yes
#
#   Do_Not_Contact          State
# 0             No          Shire
# 1             No
# 2             No
# 3             No       New York
# 4             No
# ...

# %%
df.drop(columns='index',inplace=True)
# Out:
# C:\Users\Amish Ilyas\AppData\Local\Temp\ipykernel_8744\2364643253.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns='index',inplace=True)

# %%
df
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0        1001      Frodo     Baggins  123-545-5421             Yes
# 1        1005        Jon        Snow  876-678-3469             Yes
# 2        1008   Sherlock      Holmes  876-678-3469              No
# 3        1010      Peter      Parker  123-545-5421             Yes
# 4        1013        Don      Draper  123-543-2345             Yes
# 5        1014     Leslie       Knope  876-678-3469             Yes
# 6        1015       Toby  Flenderson  304-762-2467              No
# 7        1016        Ron     Weasley  123-545-5421              No
# 8        1017   Michael        Scott  123-643-9775             Yes
# 9        1020     Anakin   Skywalker  876-678-3469             Yes
#
#   Do_Not_Contact          State
# 0             No          Shire
# 1             No
# 2             No
# 3             No       New York
# 4             No
# 5             No
# 6             No
# 7             No
# ...

# %%
Sorted_Data_By_First_Name = df.sort_values(by='First_Name',ascending=True)

# %%
Sorted_Data_By_First_Name
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 9        1020     Anakin   Skywalker  876-678-3469             Yes
# 4        1013        Don      Draper  123-543-2345             Yes
# 0        1001      Frodo     Baggins  123-545-5421             Yes
# 1        1005        Jon        Snow  876-678-3469             Yes
# 5        1014     Leslie       Knope  876-678-3469             Yes
# 8        1017   Michael        Scott  123-643-9775             Yes
# 3        1010      Peter      Parker  123-545-5421             Yes
# 7        1016        Ron     Weasley  123-545-5421              No
# 2        1008   Sherlock      Holmes  876-678-3469              No
# 6        1015       Toby  Flenderson  304-762-2467              No
#
#   Do_Not_Contact          State
# 9             No       Tatooine
# 4             No
# 0             No          Shire
# 1             No
# 5             No
# 8             No   Pennsylvania
# 3             No       New York
# ...

# %%
visual = Sorted_Data_By_First_Name.groupby(['Paying Customer','Do_Not_Contact']).agg({'Paying Customer':'count','Do_Not_Contact':'count'})

# %%
visual.plot(kind='barh')
# Out:
# <Axes: ylabel='Paying Customer,Do_Not_Contact'>

# %%
visual.plot(kind='line',subplots=True)
# Out:
# array([<Axes: xlabel='Paying Customer,Do_Not_Contact'>,
#        <Axes: xlabel='Paying Customer,Do_Not_Contact'>], dtype=object)
