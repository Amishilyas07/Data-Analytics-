# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Python\Alex the Analyst Playlist of Python\Pandas\Data_Cleaning_Pandas\unclean_data1.csv')

# %%
df
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df = df.rename(columns={'movie_title':'Movie_Title'})

# %%
df.replace('[^a-zA-z0-9]',' ',regex=True,inplace=True)

# %%
df
# Out:
#                                      Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                       723
# 1     Pirates of the Caribbean  At World s End                       302
# 2                                      Spectre                       602
# 3                        The Dark Knight Rises                       813
# 4                                  John Carter                       462
# 5                                 Spider Man 3                       392
# 6                                      Tangled                       324
# 7                      Avengers  Age of Ultron                       635
# 8                      Avengers  Age of Ultron                       635
# 9       Harry Potter and the Half Blood Prince                       375
# 10          Batman v Superman  Dawn of Justice                       673
# 11                            Superman Returns                       434
# ...

# %%
df['Movie_Title'] = df['Movie_Title'].str.strip()

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Movie_Title                14 non-null     object
#  1   num_critic_for_reviews     14 non-null     int64
#  2   duration                   11 non-null     float64
#  3   DIRECTOR_facebook_likes    12 non-null     object
#  4   actor_3_facebook_likes     14 non-null     int64
#  5   ACTOR_1_facebook_likes     14 non-null     int64
#  6   gross                      14 non-null     int64
#  7   num_voted_users            13 non-null     float64
#  8   Cast_Total_facebook_likes  12 non-null     float64
#  9   facenumber_in_poster       9 non-null      float64
#  10  num_user_for_reviews       14 non-null     int64
#  11  budget                     14 non-null     int64
#  12  title_year                 14 non-null     int64
# ...

# %%
df['duration'] = df['duration'].fillna(0)

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df['duration'].mode
# Out:
# <bound method Series.mode of 0     178.0
# 1       0.0
# 2     148.0
# 3       0.0
# 4     132.0
# 5     156.0
# 6       0.0
# 7     141.0
# 8     141.0
# 9     153.0
# 10    183.0
# 11    169.0
# 12    106.0
# 13    151.0
# Name: duration, dtype: float64>

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df['duration'] = df['duration'].replace(0.0,178.2)

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df['duration'].agg({'duration':'sum'})
# Out:
# duration    2192.6
# Name: duration, dtype: float64

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Movie_Title                14 non-null     object
#  1   num_critic_for_reviews     14 non-null     int64
#  2   duration                   14 non-null     float64
#  3   DIRECTOR_facebook_likes    12 non-null     object
#  4   actor_3_facebook_likes     14 non-null     int64
#  5   ACTOR_1_facebook_likes     14 non-null     int64
#  6   gross                      14 non-null     int64
#  7   num_voted_users            13 non-null     float64
#  8   Cast_Total_facebook_likes  12 non-null     float64
#  9   facenumber_in_poster       9 non-null      float64
#  10  num_user_for_reviews       14 non-null     int64
#  11  budget                     14 non-null     int64
#  12  title_year                 14 non-null     int64
# ...

# %%
df['DIRECTOR_facebook_likes'] = pd.to(df['DIRECTOR_facebook_likes'],errors='coerce')

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df['DIRECTOR_facebook_likes'].mean()
# Out:
# np.float64(2030.5)

# %%
df['DIRECTOR_facebook_likes'].median()
# Out:
# np.float64(152.5)

# %%
df['DIRECTOR_facebook_likes'].mode()
# Out:
# 0    10.0
# Name: DIRECTOR_facebook_likes, dtype: float64

# %%
df['DIRECTOR_facebook_likes']= df['DIRECTOR_facebook_likes'].fillna(10.0)

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Movie_Title                14 non-null     object
#  1   num_critic_for_reviews     14 non-null     int64
#  2   duration                   14 non-null     float64
#  3   DIRECTOR_facebook_likes    14 non-null     float64
#  4   actor_3_facebook_likes     14 non-null     int64
#  5   ACTOR_1_facebook_likes     14 non-null     int64
#  6   gross                      14 non-null     int64
#  7   num_voted_users            13 non-null     float64
#  8   Cast_Total_facebook_likes  12 non-null     float64
#  9   facenumber_in_poster       9 non-null      float64
#  10  num_user_for_reviews       14 non-null     int64
#  11  budget                     14 non-null     int64
#  12  title_year                 14 non-null     int64
# ...

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df['actor_3_facebook_likes'].sum()
# Out:
# np.int64(82126)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Movie_Title                14 non-null     object
#  1   num_critic_for_reviews     14 non-null     int64
#  2   duration                   14 non-null     float64
#  3   DIRECTOR_facebook_likes    14 non-null     float64
#  4   actor_3_facebook_likes     14 non-null     int64
#  5   ACTOR_1_facebook_likes     14 non-null     int64
#  6   gross                      14 non-null     int64
#  7   num_voted_users            13 non-null     float64
#  8   Cast_Total_facebook_likes  12 non-null     float64
#  9   facenumber_in_poster       9 non-null      float64
#  10  num_user_for_reviews       14 non-null     int64
#  11  budget                     14 non-null     int64
#  12  title_year                 14 non-null     int64
# ...

# %%
df[df['Cast_Total_facebook_likes'].isna()==1]
# Out:
#          Movie_Title  num_critic_for_reviews  duration  \
# 6            Tangled                     324     178.2
# 11  Superman Returns                     434     169.0
#
#     DIRECTOR_facebook_likes  actor_3_facebook_likes  ACTOR_1_facebook_likes  \
# 6                      15.0                     284                     799
# 11                     10.0                     903                   18000
#
#         gross  num_voted_users  Cast_Total_facebook_likes  \
# 6   200807262         294810.0                        NaN
# 11  200069408         240396.0                        NaN
#
#     facenumber_in_poster  num_user_for_reviews     budget  title_year  \
# 6                    1.0                   387  260000000        2010
# 11                   2.0                  2367  209000000        2006
#
#     ACTOR_2_facebook_likes  imdb_score  title_year.1
# 6                    553.0         7.8           NaN
# 11                 10000.0         6.1           NaN

# %%
df['Cast_Total_facebook_likes'].median()
# Out:
# np.float64(47202.5)

# %%
df['Cast_Total_facebook_likes'] = df['Cast_Total_facebook_likes'].fillna(47202.5)

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df['num_voted_users'].median()
# Out:
# np.float64(383056.0)

# %%
df['num_voted_users'] = df['num_voted_users'].fillna(383056.0)

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Movie_Title                14 non-null     object
#  1   num_critic_for_reviews     14 non-null     int64
#  2   duration                   14 non-null     float64
#  3   DIRECTOR_facebook_likes    14 non-null     float64
#  4   actor_3_facebook_likes     14 non-null     int64
#  5   ACTOR_1_facebook_likes     14 non-null     int64
#  6   gross                      14 non-null     int64
#  7   num_voted_users            14 non-null     float64
#  8   Cast_Total_facebook_likes  14 non-null     float64
#  9   facenumber_in_poster       9 non-null      float64
#  10  num_user_for_reviews       14 non-null     int64
#  11  budget                     14 non-null     int64
#  12  title_year                 14 non-null     int64
# ...

# %%
df['facenumber_in_poster'] = df['facenumber_in_poster'].astype('str')

# %%
df['facenumber_in_poster'] = df['facenumber_in_poster'].replace('nan','Not Avaliable',regex=False)

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df['ACTOR_2_facebook_likes'] = df['ACTOR_2_facebook_likes'].fillna(5000.0)

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df = df.drop(columns='title_year.1')

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
visual = df.groupby('title_year',).agg({'Movie_Title':'count'}).sort_values('Movie_Title',ascending=False)

# %%
visual.plot(kind='bar')
# Out:
# <Axes: xlabel='title_year'>

# %%
df
# Out:
#                                    Movie_Title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean  At World s End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers  Age of Ultron                     635
# 8                      Avengers  Age of Ultron                     635
# 9       Harry Potter and the Half Blood Prince                     375
# 10          Batman v Superman  Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
df.set_index('Movie_Title',inplace=True)

# %%
df
# Out:
#                                             num_critic_for_reviews  duration  \
# Movie_Title
# Avatar                                                         723     178.0
# Pirates of the Caribbean  At World s End                       302     178.2
# Spectre                                                        602     148.0
# The Dark Knight Rises                                          813     178.2
# John Carter                                                    462     132.0
# Spider Man 3                                                   392     156.0
# Tangled                                                        324     178.2
# Avengers  Age of Ultron                                        635     141.0
# Avengers  Age of Ultron                                        635     141.0
# Harry Potter and the Half Blood Prince                         375     153.0
# Batman v Superman  Dawn of Justice                             673     183.0
# ...

# %%
df
# Out:
#                                             num_critic_for_reviews  duration  \
# Movie_Title
# Avatar                                                         723     178.0
# Pirates of the Caribbean  At World s End                       302     178.2
# Spectre                                                        602     148.0
# The Dark Knight Rises                                          813     178.2
# John Carter                                                    462     132.0
# Spider Man 3                                                   392     156.0
# Tangled                                                        324     178.2
# Avengers  Age of Ultron                                        635     141.0
# Avengers  Age of Ultron                                        635     141.0
# Harry Potter and the Half Blood Prince                         375     153.0
# Batman v Superman  Dawn of Justice                             673     183.0
# ...

# %%
visual2 = df.filter(items=['title_year'],axis=1)

# %%
visual2.plot(kind='line',figsize=(30,5))
# Out:
# <Axes: xlabel='Movie_Title'>

# %%
visual2 = df.filter(items=['title_year'],axis=1)

# %%
visual2.sort_values(by='title_year',ascending=False)
# Out:
#                                             title_year
# Movie_Title
# Batman v Superman  Dawn of Justice                2016
# Spectre                                           2015
# Avengers  Age of Ultron                           2015
# Avengers  Age of Ultron                           2015
# John Carter                                       2012
# The Dark Knight Rises                             2012
# Tangled                                           2010
# Harry Potter and the Half Blood Prince            2009
# Avatar                                            2009
# Quantum of Solace                                 2008
# Spider Man 3                                      2007
# Pirates of the Caribbean  At World s End          2007
# Superman Returns                                  2006
# Pirates of the Caribbean  Dead Man s Chest        2006
