# %%
import pandas as pd

# %%
df = pd.read_excel(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Python\Alex the Analyst Playlist of Python\Pandas\Movie-Data.xlsx')

# %%
df
# Out:
#                                    Movie Title Release Date  \
# 0                          10 Cloverfield Lane   2016-03-08
# 1    13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                       2 Guns   2013-08-02
# 3                               21 Jump Street   2012-03-16
# 4                               22 Jump Street   2014-06-04
# ..                                         ...          ...
# 503                 X-Men: Days of Future Past   2014-05-10
# 504                                You're Next   2013-08-23
# 505                           Zero Dark Thirty   2012-12-19
# 506  Zhong Kui: Snow Girl and the Dark Crystal   2015-02-19
# 507                                Zoolander 2   2016-02-12
#
#                                          Wikipedia URL     Genre  \
# 0    https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 1    https://en.wikipedia.org/wiki/13_Hours:_The_Se...    Action
# ...

# %%
by_Movies = df.set_index('Movie Title')

# %%
Most_Revenue_Movies = by_Movies.filter(items=['Budget','Revenue'],axis=1).sort_values(by='Revenue',ascending=False)

# %%
Most_Revenue_Movies
# Out:
#                                                 Budget    Revenue
# Movie Title
# Despicable Me 2                               76000000  970800000
# The Hobbit: The Battle of the Five Armies    250000000  956000000
# Ice Age: Continental Drift                    95000000  877000000
# Batman v Superman: Dawn of Justice           250000000  872700000
# The Twilight Saga: Breaking Dawn – Part 2    120000000  829700000
# ...                                                ...        ...
# The Letters                                    1000000    1600000
# Lazer Team                                     2400000    1600000
# The Oogieloves in the Big Balloon Adventure   20000000    1100000
# Ain't Them Bodies Saints                       4000000    1000000
# No One Lives                                   2900000    1000000
#
# [508 rows x 2 columns]

# %%
Top_20_Movies_By_Revenue = Most_Revenue_Movies.head(20)

# %%
Top_20_Movies_By_Revenue
# Out:
#                                               Budget    Revenue
# Movie Title
# Despicable Me 2                             76000000  970800000
# The Hobbit: The Battle of the Five Armies  250000000  956000000
# Ice Age: Continental Drift                  95000000  877000000
# Batman v Superman: Dawn of Justice         250000000  872700000
# The Twilight Saga: Breaking Dawn – Part 2  120000000  829700000
# Fast & Furious 6                           160000000  788700000
# Deadpool                                    58000000  782600000
# The Amazing Spider-Man                     230000000  757900000
# The Hunger Games: Mockingjay – Part 1      125000000  755400000
# X-Men: Days of Future Past                 200000000  747900000
# Madagascar 3: Europe's Most Wanted         145000000  746900000
# The Secret Life of Pets                     75000000  724900000
# Captain America: The Winter Soldier        170000000  714400000
# ...

# %%
Top_20_Movies_By_Revenue.filter(like='Amazing',axis= 0)
# Out:
#                            Budget    Revenue
# Movie Title
# The Amazing Spider-Man  230000000  757900000
