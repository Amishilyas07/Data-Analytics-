# %%
import pandas as pd

# %%
df = pd.read_excel(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Python\Alex the Analyst Playlist of Python\Pandas\world_population_excel_workbook.xlsx')

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El Aai̼n    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df.agg({'Country':'count'})
# Out:
# Country    234
# dtype: int64

# %%
countries = df.sort_values(by='2022 Population',ascending=False).head(10)

# %%
countries
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# ...

# %%
Filtering_Country = countries.set_index('Country')

# %%
Filtering_Country
# Out:
#                Rank CCA3           Capital      Continent  2022 Population  \
# Country
# China             1  CHN           Beijing           Asia       1425887337
# India             2  IND         New Delhi           Asia       1417173173
# United States     3  USA  Washington, D.C.  North America        338289857
# Indonesia         4  IDN           Jakarta           Asia        275501339
# Pakistan          5  PAK         Islamabad           Asia        235824862
# Nigeria           6  NGA             Abuja         Africa        218541212
# Brazil            7  BRA          Brasilia  South America        215313498
# Bangladesh        8  BGD             Dhaka           Asia        171186372
# Russia            9  RUS            Moscow         Europe        144713314
# Mexico           10  MEX       Mexico City  North America        127504125
#
#                2020 Population  2015 Population  2010 Population  \
# Country
# ...

# %%
Filtering_Country.filter(items=['2022 Population','Growth Rate'],axis=1)
# Out:
#                2022 Population  Growth Rate
# Country
# China               1425887337       1.0000
# India               1417173173       1.0068
# United States        338289857       1.0038
# Indonesia            275501339       1.0064
# Pakistan             235824862       1.0191
# Nigeria              218541212       1.0241
# Brazil               215313498       1.0046
# Bangladesh           171186372       1.0108
# Russia               144713314       0.9973
# Mexico               127504125       1.0063

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El Aai̼n    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
Growth_Rate = df.groupby('Country').agg({'Growth Rate':'sum'}).sort_values(by='Growth Rate',ascending=False)

# %%
Growth_Rate.head(50)
# Out:
#                           Growth Rate
# Country
# Moldova                        1.0691
# Poland                         1.0404
# Niger                          1.0378
# Syria                          1.0376
# Slovakia                       1.0359
# DR Congo                       1.0325
# Mayotte                        1.0319
# Chad                           1.0316
# Angola                         1.0315
# Mali                           1.0314
# Somalia                        1.0312
# Uganda                         1.0304
# Tanzania                       1.0300
# Zambia                         1.0280
# Mozambique                     1.0278
# Benin                          1.0274
# Burundi                        1.0270
# Sudan                          1.0267
# Hungary                        1.0265
# Cameroon                       1.0263
# Mauritania                     1.0263
# Senegal                        1.0261
# Malawi                         1.0259
# ...

# %%
Countries_in_Each_Continent = df.groupby('Continent').agg({'Country':'count'})

# %%
Countries_in_Each_Continent
# Out:
#                Country
# Continent
# Africa              57
# Asia                50
# Europe              50
# North America       40
# Oceania             23
# South America       14
