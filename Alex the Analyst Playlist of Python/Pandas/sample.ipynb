# %%
import pandas as pd

# %%
df = pd.read_excel(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Python\Alex the Analyst Playlist of Python\Pandas\Movie-Data.xlsx')

# %%
df.shape

# %%
df.head()

# %%
df

# %%
df2 =pd.set_option('display.max.rows',10)

# %%
df2 = df

# %%
df
# Out:
#                                    Movie Title Release Date  \
# 0                          10 Cloverfield Lane   2016-03-08
# 1    13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                       2 Guns   2013-08-02
# 3                               21 Jump Street   2012-03-16
# 4                               22 Jump Street   2014-06-04
# ..                                         ...          ...
# 503                 X-Men: Days of Future Past   2014-05-10
# 504                                You're Next   2013-08-23
# 505                           Zero Dark Thirty   2012-12-19
# 506  Zhong Kui: Snow Girl and the Dark Crystal   2015-02-19
# 507                                Zoolander 2   2016-02-12
#
#                                          Wikipedia URL     Genre  \
# 0    https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 1    https://en.wikipedia.org/wiki/13_Hours:_The_Se...    Action
# ...

# %%
df.head()
# Out:
#                                  Movie Title Release Date  \
# 0                        10 Cloverfield Lane   2016-03-08
# 1  13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                     2 Guns   2013-08-02
# 3                             21 Jump Street   2012-03-16
# 4                             22 Jump Street   2014-06-04
#
#                                        Wikipedia URL     Genre  \
# 0  https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 1  https://en.wikipedia.org/wiki/13_Hours:_The_Se...    Action
# 2               https://en.wikipedia.org/wiki/2_Guns    Action
# 3  https://en.wikipedia.org/wiki/21_Jump_Street_(...    Comedy
# 4       https://en.wikipedia.org/wiki/22_Jump_Street    Action
#
#         Director (1)  Director (2)                 Cast (1)  \
# 0   Dan Trachtenberg           NaN  Mary Elizabeth Winstead
# 1        Michael Bay           NaN         James Badge Dale
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Movie Title    508 non-null    object
#  1   Release Date   508 non-null    datetime64[ns]
#  2   Wikipedia URL  508 non-null    object
#  3   Genre          508 non-null    object
#  4   Director (1)   508 non-null    object
#  5   Director (2)   41 non-null     object
#  6   Cast (1)       508 non-null    object
#  7   Cast (2)       503 non-null    object
#  8   Cast (3)       485 non-null    object
#  9   Cast (4)       452 non-null    object
#  10  Cast (5)       389 non-null    object
#  11  Budget         508 non-null    int64
#  12  Revenue        508 non-null    int64
# dtypes: datetime64[ns](1), int64(2), object(10)
# memory usage: 51.7+ KB

# %%
df.head()
# Out:
#                                  Movie Title Release Date  \
# 0                        10 Cloverfield Lane   2016-03-08
# 1  13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                     2 Guns   2013-08-02
# 3                             21 Jump Street   2012-03-16
# 4                             22 Jump Street   2014-06-04
#
#                                        Wikipedia URL     Genre  \
# 0  https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 1  https://en.wikipedia.org/wiki/13_Hours:_The_Se...    Action
# 2               https://en.wikipedia.org/wiki/2_Guns    Action
# 3  https://en.wikipedia.org/wiki/21_Jump_Street_(...    Comedy
# 4       https://en.wikipedia.org/wiki/22_Jump_Street    Action
#
#         Director (1)  Director (2)                 Cast (1)  \
# 0   Dan Trachtenberg           NaN  Mary Elizabeth Winstead
# 1        Michael Bay           NaN         James Badge Dale
# ...

# %%
Thriller_Movies = df[df['Genre'].str.contains('Thriller')]

# %%
df2 = Thriller_Movies

# %%
Countries_First = df.set_index('Genre')

# %%
Countries_First
# Out:
#                   Movie Title Release Date  \
# Genre
# Thriller  10 Cloverfield Lane   2016-03-08
# Thriller    A Most Wanted Man   2014-01-19
# Thriller        Don't Breathe   2016-08-26
# Thriller       Eye in the Sky   2015-09-11
# Thriller                Nerve   2016-07-27
# ...                       ...          ...
# Thriller           The Gunman   2015-03-20
# Thriller     The November Man   2014-08-27
# Thriller      The Perfect Guy   2015-09-02
# Thriller            The Raven   2012-04-27
# Thriller         The Revenant   2015-12-25
#
#                                               Wikipedia URL  \
# Genre
# Thriller  https://en.wikipedia.org/wiki/10_Cloverfield_Lane
# Thriller  https://en.wikipedia.org/wiki/A_Most_Wanted_Ma...
# Thriller  https://en.wikipedia.org/wiki/Don%2527t_Breath...
# Thriller  https://en.wikipedia.org/wiki/Eye_in_the_Sky_(...
# Thriller    https://en.wikipedia.org/wiki/Nerve_(2016_film)
# ...                                                     ...
# ...

# %%
df
# Out:
#              Movie Title Release Date  \
# 0    10 Cloverfield Lane   2016-03-08
# 14     A Most Wanted Man   2014-01-19
# 88         Don't Breathe   2016-08-26
# 106       Eye in the Sky   2015-09-11
# 220                Nerve   2016-07-27
# ..                   ...          ...
# 376           The Gunman   2015-03-20
# 416     The November Man   2014-08-27
# 421      The Perfect Guy   2015-09-02
# 431            The Raven   2012-04-27
# 432         The Revenant   2015-12-25
#
#                                          Wikipedia URL     Genre  \
# 0    https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 14   https://en.wikipedia.org/wiki/A_Most_Wanted_Ma...  Thriller
# 88   https://en.wikipedia.org/wiki/Don%2527t_Breath...  Thriller
# 106  https://en.wikipedia.org/wiki/Eye_in_the_Sky_(...  Thriller
# 220    https://en.wikipedia.org/wiki/Nerve_(2016_film)  Thriller
# ..                                                 ...       ...
# ...

# %%
df
# Out:
#              Movie Title Release Date  \
# 0    10 Cloverfield Lane   2016-03-08
# 14     A Most Wanted Man   2014-01-19
# 88         Don't Breathe   2016-08-26
# 106       Eye in the Sky   2015-09-11
# 220                Nerve   2016-07-27
# ..                   ...          ...
# 376           The Gunman   2015-03-20
# 416     The November Man   2014-08-27
# 421      The Perfect Guy   2015-09-02
# 431            The Raven   2012-04-27
# 432         The Revenant   2015-12-25
#
#                                          Wikipedia URL     Genre  \
# 0    https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 14   https://en.wikipedia.org/wiki/A_Most_Wanted_Ma...  Thriller
# 88   https://en.wikipedia.org/wiki/Don%2527t_Breath...  Thriller
# 106  https://en.wikipedia.org/wiki/Eye_in_the_Sky_(...  Thriller
# 220    https://en.wikipedia.org/wiki/Nerve_(2016_film)  Thriller
# ..                                                 ...       ...
# ...

# %%
df = pd.read_excel(r'E:\Data Analyst Roadmap\Google Data Analytics Certificate Course\Python\Alex the Analyst Playlist of Python\Pandas\Movie-Data.xlsx')

# %%
df
# Out:
#                                    Movie Title Release Date  \
# 0                          10 Cloverfield Lane   2016-03-08
# 1    13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                       2 Guns   2013-08-02
# 3                               21 Jump Street   2012-03-16
# 4                               22 Jump Street   2014-06-04
# ..                                         ...          ...
# 503                 X-Men: Days of Future Past   2014-05-10
# 504                                You're Next   2013-08-23
# 505                           Zero Dark Thirty   2012-12-19
# 506  Zhong Kui: Snow Girl and the Dark Crystal   2015-02-19
# 507                                Zoolander 2   2016-02-12
#
#                                          Wikipedia URL     Genre  \
# 0    https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 1    https://en.wikipedia.org/wiki/13_Hours:_The_Se...    Action
# ...

# %%
genreList = ['Action','Comedy','Horror']
#way1 = df[df['Genre'].str.contains('Action')]
way2 = df[df['Genre'].isin(genreList)].sort_values('Revenue',ascending=False)

# %%
way2
# Out:
#                             Movie Title Release Date  \
# 82                      Despicable Me 2   2013-06-20
# 35   Batman v Superman: Dawn of Justice   2016-03-19
# 108                    Fast & Furious 6   2013-05-17
# 79                             Deadpool   2016-02-08
# 336              The Amazing Spider-Man   2012-07-03
# ..                                  ...          ...
# 443                    The Sweet Escape   2015-06-10
# 161                      Jane Got a Gun   2016-01-29
# 7                                    71   2014-02-07
# 475                                Tusk   2014-09-06
# 226                        No One Lives   2013-05-10
#
#                                          Wikipedia URL   Genre  \
# 82       https://en.wikipedia.org/wiki/Despicable_Me_2  Comedy
# 35   https://en.wikipedia.org/wiki/Batman_v_Superma...  Action
# 108  https://en.wikipedia.org/wiki/Fast_%2526_Furio...  Action
# 79       https://en.wikipedia.org/wiki/Deadpool_(film)  Action
# ...

# %%
way2.set_index('Movie Title')
# Out:
#                                    Release Date  \
# Movie Title
# Despicable Me 2                      2013-06-20
# Batman v Superman: Dawn of Justice   2016-03-19
# Fast & Furious 6                     2013-05-17
# Deadpool                             2016-02-08
# The Amazing Spider-Man               2012-07-03
# ...                                         ...
# The Sweet Escape                     2015-06-10
# Jane Got a Gun                       2016-01-29
# 71                                   2014-02-07
# Tusk                                 2014-09-06
# No One Lives                         2013-05-10
#
#                                                                         Wikipedia URL  \
# Movie Title
# Despicable Me 2                         https://en.wikipedia.org/wiki/Despicable_Me_2
# Batman v Superman: Dawn of Justice  https://en.wikipedia.org/wiki/Batman_v_Superma...
# Fast & Furious 6                    https://en.wikipedia.org/wiki/Fast_%2526_Furio...
# ...

# %%
way2.filter(items=[],axis=0)
# Out:
# Empty DataFrame
# Columns: [Movie Title, Release Date, Wikipedia URL, Genre, Director (1), Director (2), Cast (1), Cast (2), Cast (3), Cast (4), Cast (5), Budget, Revenue]
# Index: []

# %%
df2.filter(like='A Most ',axis=0)
# Out:
# Empty DataFrame
# Columns: [Movie Title, Release Date, Wikipedia URL, Genre, Director (1), Director (2), Cast (1), Cast (2), Cast (3), Cast (4), Cast (5), Budget, Revenue]
# Index: []

# %%
Movies = df.set_index('Movie Title')

# %%
Movies.sort_values(['Revenue'],ascending=False).filter(items=['Revenue','Budget'],axis=1)
# Out:
#                                                Revenue     Budget
# Movie Title
# Despicable Me 2                              970800000   76000000
# The Hobbit: The Battle of the Five Armies    956000000  250000000
# Ice Age: Continental Drift                   877000000   95000000
# Batman v Superman: Dawn of Justice           872700000  250000000
# The Twilight Saga: Breaking Dawn – Part 2    829700000  120000000
# ...                                                ...        ...
# The Letters                                    1600000    1000000
# Lazer Team                                     1600000    2400000
# The Oogieloves in the Big Balloon Adventure    1100000   20000000
# Ain't Them Bodies Saints                       1000000    4000000
# No One Lives                                   1000000    2900000
#
# [508 rows x 2 columns]

# %%
sorted_movies = Movies.sort_values(['Revenue'],ascending=False).filter(items=['Revenue','Budget'],axis=1)

# %%
sorted_movies
# Out:
#                                                Revenue     Budget
# Movie Title
# Despicable Me 2                              970800000   76000000
# The Hobbit: The Battle of the Five Armies    956000000  250000000
# Ice Age: Continental Drift                   877000000   95000000
# Batman v Superman: Dawn of Justice           872700000  250000000
# The Twilight Saga: Breaking Dawn – Part 2    829700000  120000000
# ...                                                ...        ...
# The Letters                                    1600000    1000000
# Lazer Team                                     1600000    2400000
# The Oogieloves in the Big Balloon Adventure    1100000   20000000
# Ain't Them Bodies Saints                       1000000    4000000
# No One Lives                                   1000000    2900000
#
# [508 rows x 2 columns]

# %%
sorted_movies.filter(like='Desp',axis=0)
# Out:
#                    Revenue    Budget
# Movie Title
# Despicable Me 2  970800000  76000000
