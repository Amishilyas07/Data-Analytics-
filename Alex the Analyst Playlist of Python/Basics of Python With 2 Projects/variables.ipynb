# %% [markdown]
# # Variable in Python

# %%
x = 5
print(x)
# Out:
# 5

# %%
x = 5
print(x)
# Out:
# 5

# %%
print("WWE")
# Out:
# WWE

# %%
x = 5

print(x)
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
y = "Amish Ilyas"

print(y)
# Out:
# Amish Ilyas

# %%
type(x)

type(y)
# Out:
# str

# %%
type(x)
# Out:
# int

# %%
type(x)
type(y)
# Out:
# str

# %%
print(y)
# Out:
# Amish Ilyas

# %%
y= "wwe"

# %%
print(y)
# Out:
# wwe

# %%
x,y,z = "Amish" , "John" , "Henry"

# %%
print(x)
print(y)
print(z)
# Out:
# Amish
# John
# Henry

# %%
x=y=z= "Struggle is Real"
print(x)
print(y)
print(z)
# Out:
# Struggle is Real
# Struggle is Real
# Struggle is Real

# %%
Games = ["FIFA","WWE","God Of War"]
print(Games)
# Out:
# ['FIFA', 'WWE', 'God Of War']

# %%
x,y,z = Games

print(x)
print(y)
print(z)
# Out:
# FIFA
# WWE
# God Of War

# %%
# Camel Case
# Test Variable Case 
favoriteFruitsOfMine = ["Apple","Orange","Banana"]
print(favoriteFruitsOfMine)
# Out:
# ['Apple', 'Orange', 'Banana']

# %%
# Pascal Case 
MyCars = ["Bugatti","BMW"]
print(MyCars)
# Out:
# ['Bugatti', 'BMW']

# %%
# Snake Case

my_name = "Amish"
print(my_name)
# Out:
# Amish

# %%
x = "Amish" + "Ilyas"
print(x)
# Out:
# AmishIlyas
