# %% [markdown]
# # Converting Data Types

# %%
myNumber = 7
type(myNumber)
# Out:
# int

# %%
myNumber2 = '8'

result = myNumber + myNumber2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 myNumber2 = '8'
# ----> 3 result = myNumber + myNumber2
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
int(myNumber2)
# Out:
# 8

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(result)
#
# NameError: name 'result' is not defined

# %%
result = myNumber +myNumber2
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = myNumber +myNumber2
#       2 print(result)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
converted_num2 = int(myNumber2)

# %%
result = myNumber + converted_num2
print(result)
# Out:
# 15

# %%
myList = [1,1,2,5,7,4,77,22]
print(myList)
# Out:
# [1, 1, 2, 5, 7, 4, 77, 22]

# %%
set_converted_List = set(myList)

print(set_converted_List)
# Out:
# {1, 2, 4, 5, 7, 77, 22}

# %%
dictionary = {'Name': 'Amish','Age':22}
print(dictionary)
# Out:
# {'Name': 'Amish', 'Age': 22}

# %%
dictionary.keys()
# Out:
# dict_keys(['Name', 'Age'])

# %%
dictionary.values()
# Out:
# dict_values(['Amish', 22])

# %%
list_keys = list(dictionary.keys())

# %%
list_values =list(dictionary.values())

# %%
print(list_keys)
# Out:
# ['Name', 'Age']
