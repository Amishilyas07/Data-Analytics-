# %% [markdown]
# # IF Statements

# %%
if 25 > 10
# Out:
#   Cell In[1], line 1
#     if 25 > 10
#               ^
# SyntaxError: expected ':'

# %%
if 25 > 10 :
    print("25 greater than 10")
# Out:
# 25 greater than 10

# %%
if 10 < 25 :
    print("10 is < 25")
# Out:
# 10 is < 25

# %%
name = "Ali"
if name == "Amish" :
    print("You are Logged in")
else:
    print("You are Not Amish")
# Out:
# You are Not Amish

# %%
if name == "krk":
    print("Welcome User")
elif name == "Ali":
    print("Welcome User")
else: print("You Are Not User")
# Out:
# Welcome User

# %%
if 5 > 1 :
    print("Worked")
elif 4 > 1:
    print("Also Worked")
else:print("Not Worker")
# Out:
# Worked

# %%
if 1 > 5 :
    print("Worked")
elif 1 > 1:
    print("Also Worked")
else:print("Not Worker")
# Out:
# Not Worker

# %%
name = "Ali"
if name == "kashif":
    print("Worked")
elif name == "Umar":
    print("Wroked")
else:print("Not Worked")
# Out:
# Not Worked

# %%
if (25>26) or (25<2):
    print("It Worked")
elif (25<5) or (25>36):
    print("It Also Worked")
else: print("Error")
# Out:
# Error

# %%
if(25>2) and (25>5):
    if(5==5):
        print("Nested If Worked")
# Out:
# Nested If Worked
