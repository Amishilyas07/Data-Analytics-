# %%
10==10
# Out:
# True

# %%
'Car'=='Car'
# Out:
# True

# %%
x = "SRK"
y = 'KRK'
x==y
# Out:
# False

# %%
(10>50) or (10==10)
# Out:
# True

# %%
(10>50) and (10>60)
# Out:
# False

# %%
games = 'Tekken WWE FIFA'
'Tekken' in games
# Out:
# True

# %%
my_numbers = [1,6,3,5]

# %%
5 in my_numbers
# Out:
# True

# %%
8 not in my_numbers
# Out:
# True
