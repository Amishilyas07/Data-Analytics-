# %% [markdown]
# Here's a **realistic synthetic dataset** that mirrors what a data analyst might work with in an e-commerce or retail company. It includes customer demographics, buying behavior, and satisfaction metrics.
#
# ---
#
# ### 🔢 **Dataset Overview**
# | Column | Description |
# |--------|-------------|
# | `Customer_ID` | Unique customer identifier |
# | `Gender` | Customer gender |
# | `Age` | Customer age |
# | `Membership_Type` | Loyalty program tier (Basic, Silver, Gold, Platinum) |
# | `Items_Purchased` | Number of items purchased |
# | `Total_Spend` | Total amount spent in dollars |
# | `Discount_Applied` | Whether discount was applied (0 = No, 1 = Yes) |
# | `Days_Since_Last_Purchase` | Days since customer last bought something |
# | `Average_Rating` | Average product rating given by the customer |
# | `Satisfaction_Score` | Score between 0-1 on satisfaction (like NPS proxy) |
# | `Region` | Region where customer is based |
#
# ---
#
# ### ✅ **What’s Next: Practice Topics + Real-World Scenarios**
#
# I’ll now give you **topics** with an explanation, **example questions**, and tell you how this is **relevant in real jobs/interviews**. You’ll solve the questions in Python using this dataset.
#
# ---
#
# #### 1. **Descriptive Statistics**
# **🔍 What:** Measures like mean, median, mode, range, standard deviation.
#
# **📌 Questions:**
# - What is the average `Total_Spend`, median, and standard deviation?
# - Compare average `Total_Spend` by `Membership_Type`.
#
# **💼 Real-life Use:** Helps summarize and report KPIs. You’d do this in dashboards or to profile customers.
#
# ---
#
# #### 2. **Probability**
# **🔍 What:** Likelihood of an event occurring.
#
# **📌 Questions:**
# - What’s the probability a customer is from the **West**?
# - What is the probability a customer gave a **5-star** rating given a **discount** was applied?
#
# **💼 Real-life Use:** Used in churn modeling, campaign targeting, and risk assessment.
#
# ---
#
# #### 3. **Sampling**
# **🔍 What:** Selecting a subset of data to estimate population parameters.
#
# **📌 Questions:**
# - Take a sample of 300 customers. What’s the sample mean for `Total_Spend`?
# - How close is this sample to the actual population?
#
# **💼 Real-life Use:** Often you can't access entire data (e.g., surveys), so you make inferences from samples.
#
# ---
#
# #### 4. **Hypothesis Testing**
# **🔍 What:** Test assumptions using p-values and statistical significance.
#
# **📌 Questions:**
# - Is there a significant difference in `Total_Spend` between **Male** and **Female** customers?
# - Does applying a **discount** significantly affect the **Average Rating**?
#
# **💼 Real-life Use:** Used in A/B testing, experimentation, and marketing strategies.
#
# ---
#
# #### 5. **Correlation**
# **🔍 What:** Measures relationship strength between two variables.
#
# **📌 Questions:**
# - Is there a correlation between `Age` and `Satisfaction_Score`?
# - What’s the correlation between `Items_Purchased` and `Total_Spend`?
#
# **💼 Real-life Use:** Used to find meaningful relationships for prediction or strategy.
#
# ---
#
# #### 6. **Regression**
# **🔍 What:** Predicts one variable based on others.
#
# **📌 Questions:**
# - Can we predict `Total_Spend` from `Items_Purchased`?
# - Build a linear regression model for it.
#
# **💼 Real-life Use:** Used in forecasting revenue, predicting churn, estimating lifetime value (LTV).
#
# ---
#
# Would you like me to generate **Jupyter Notebook-style code templates** for each of these topics with space for you to fill in answers — like a guided exercise workbook?
